# %%
# Forked from excellent kernel : https://www.kaggle.com/jsaguiar/updated-0-792-lb-lightgbm-with-simple-features
# From Kaggler : https://www.kaggle.com/jsaguiar
# Just added a few features so I thought I had to make release it as well...

import numpy as np
import pandas as pd
import gc
import time
from contextlib import contextmanager
import lightgbm as lgb
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import KFold, StratifiedKFold
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import csv

# %%
lgb.__version__
# Out:
# '2.2.0'

# %%
final_df = pd.read_csv('../../datasets/homeCredit/BDSE12_03G_HomeCredit_V2.csv')

# %%
test_df = pd.read_csv('../../datasets/homeCredit/BDSE12_03G_HomeCredit_V2.csv')

# %%
def process_dataframe(input_df, encoder_dict=None):
    """ Process a dataframe into a form useable by LightGBM """

    # Label encode categoricals
    categorical_feats = input_df.columns[input_df.dtypes == 'object']
    categorical_feats = categorical_feats
    encoder_dict = {}
    for feat in categorical_feats:
        encoder = LabelEncoder()
        input_df[feat] = encoder.fit_transform(input_df[feat].fillna('NULL'))
        encoder_dict[feat] = encoder

    return input_df, categorical_feats.tolist(), encoder_dict

test_df, categorical_feats, encoder_dict = process_dataframe(input_df=test_df)

# %% [markdown]
# # LightGBM 模型

# %%
def kfold_lightgbm(df, num_folds = 5, stratified = True, debug= False, modeltype = 'goss', epoch = 2000):
    # Divide in training/validation and test data
    train_df = df[df['TARGET'].notnull()]
    test_df = df[df['TARGET'].isnull()]
    print("Starting LightGBM {}. Train shape: {}, test shape: {}".format(modeltype, train_df.shape, test_df.shape))
    del df
    gc.collect()
    # Cross validation model
    if stratified:
        folds = StratifiedKFold(n_splits= num_folds, shuffle=True, random_state=1001)
    else:
        folds = KFold(n_splits= num_folds, shuffle=True, random_state=1001)
    # Create arrays and dataframes to store results
    oof_preds = np.zeros(train_df.shape[0])
    sub_preds = np.zeros(test_df.shape[0])
    feature_importance_df = pd.DataFrame()
    feats = [f for f in train_df.columns if f not in ['TARGET','SK_ID_CURR','SK_ID_BUREAU','SK_ID_PREV','index']]
    
    for n_fold, (train_idx, valid_idx) in enumerate(folds.split(train_df[feats], train_df['TARGET'])):
        dtrain = lgb.Dataset(data=train_df[feats].iloc[train_idx], 
                             label=train_df['TARGET'].iloc[train_idx], 
                             free_raw_data=False, silent=True)
        dvalid = lgb.Dataset(data=train_df[feats].iloc[valid_idx], 
                             label=train_df['TARGET'].iloc[valid_idx], 
                             free_raw_data=False, silent=True)

        # LightGBM parameters found by Bayesian optimization
        params = {
            'objective': 'binary',
            'boosting_type': modeltype,
            'nthread': 5,
            'learning_rate': 0.013803211212539657,  # 0.02,
            'num_leaves': 20, #20,33
            'colsample_bytree': 0.9497036,
            'subsample': 0.5381263969882377, #0.8715623,
            'subsample_freq': 0,
            'max_depth': 8, #8,7
            'reg_alpha': 0.6618734111073816, #0.041545473,
            'reg_lambda': 0.320433363007782, #0.0735294,
            'min_split_gain': 0.07276947619457204,#0.0222415
            'min_child_weight': 57.725650927715265, # 60,39
            'seed': 564,
            'verbose': 1000,
            'metric': 'auc',
#             'device' : 'gpu',
#             'gpu_platform_id': 0,
#             'gpu_device_id':0
        }
        
        clf = lgb.train(
            params=params,
            train_set=dtrain,
            num_boost_round=epoch,
            valid_sets=[dtrain, dvalid],
            early_stopping_rounds=2000,
            verbose_eval=1000
        )

        oof_preds[valid_idx] = clf.predict(dvalid.data)
        sub_preds += clf.predict(test_df[feats]) / folds.n_splits

        fold_importance_df = pd.DataFrame()
        fold_importance_df["feature"] = feats
        fold_importance_df["importance"] = clf.feature_importance(importance_type='gain')
        fold_importance_df["fold"] = n_fold + 1
        feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
        print('Fold {:2d} AUC : {:.6f}'.format(n_fold + 1, roc_auc_score(dvalid.label, oof_preds[valid_idx])))
        print()
        del clf, dtrain, dvalid
        gc.collect()

    print('Full AUC score : {:.6f}'.format(roc_auc_score(train_df['TARGET'], oof_preds)))
    # Write submission file and plot feature importance
    if not debug:
        sub_df = test_df[['SK_ID_CURR']].copy()
        sub_df['TARGET'] = sub_preds
        sub_df[['SK_ID_CURR', 'TARGET']].to_csv('submission_LightGBM.csv', index= False)
    display_importances(feature_importance_df)
    return feature_importance_df

# Display/plot feature importance
def display_importances(feature_importance_df_):
    cols = feature_importance_df_[["feature", "importance"]].groupby("feature").mean().sort_values(by="importance", ascending=False)[:40].index
    best_features = feature_importance_df_.loc[feature_importance_df_.feature.isin(cols)]
    plt.figure(figsize=(8, 10))
    sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False))
    plt.title('LightGBM Features (avg over folds)')
    plt.tight_layout
    plt.savefig('lgbm_importances01.png')

# %%
init_time = time.time()
kfold_lightgbm(test_df, 5, modeltype = 'goss', epoch = 5000)
print("Elapsed time={:5.2f} sec.".format(time.time() - init_time))
# Out:
# Starting LightGBM goss. Train shape: (307511, 798), test shape: (48744, 798)
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.825563	valid_1's auc: 0.793763
# [2000]	training's auc: 0.854628	valid_1's auc: 0.796142
# Early stopping, best iteration is:
# [2733]	training's auc: 0.871335	valid_1's auc: 0.796563
# Fold  1 AUC : 0.796576
#
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.825978	valid_1's auc: 0.788935
# [2000]	training's auc: 0.855102	valid_1's auc: 0.791908
# Early stopping, best iteration is:
# [2512]	training's auc: 0.867196	valid_1's auc: 0.792268
# Fold  2 AUC : 0.792269
#
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.8259	valid_1's auc: 0.789635
# [2000]	training's auc: 0.85494	valid_1's auc: 0.793148
# [3000]	training's auc: 0.877436	valid_1's auc: 0.793994
# Early stopping, best iteration is:
# [3048]	training's auc: 0.878414	valid_1's auc: 0.794053
# Fold  3 AUC : 0.794066
#
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.82493	valid_1's auc: 0.793937
# [2000]	training's auc: 0.854214	valid_1's auc: 0.79722
# [3000]	training's auc: 0.876915	valid_1's auc: 0.798239
# Early stopping, best iteration is:
# [3525]	training's auc: 0.887056	valid_1's auc: 0.798569
# Fold  4 AUC : 0.798562
#
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.82655	valid_1's auc: 0.785177
# [2000]	training's auc: 0.855533	valid_1's auc: 0.788123
# [3000]	training's auc: 0.87776	valid_1's auc: 0.788755
# Early stopping, best iteration is:
# [3022]	training's auc: 0.878161	valid_1's auc: 0.788777
# Fold  5 AUC : 0.788770
#
# Full AUC score : 0.794003
# Elapsed time=1875.65 sec.

# %% [markdown]
# ## boosting_type：gbdt

# %%
init_time = time.time()
kfold_lightgbm(final_df, 5, modeltype = 'gbdt', epoch = 5000)
print("Elapsed time={:5.2f} sec.".format(time.time() - init_time))
# Out:
# Starting LightGBM gbdt. Train shape: (307511, 932), test shape: (48744, 932)
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.824042	valid_1's auc: 0.793296
# [2000]	training's auc: 0.851562	valid_1's auc: 0.795033
# [3000]	training's auc: 0.873116	valid_1's auc: 0.795777
# Early stopping, best iteration is:
# [3426]	training's auc: 0.881261	valid_1's auc: 0.795899
# Fold  1 AUC : 0.795909
#
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.824102	valid_1's auc: 0.787374
# [2000]	training's auc: 0.851172	valid_1's auc: 0.790429
# [3000]	training's auc: 0.873493	valid_1's auc: 0.790747
# Early stopping, best iteration is:
# [3759]	training's auc: 0.888024	valid_1's auc: 0.791048
# Fold  2 AUC : 0.791043
#
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.823888	valid_1's auc: 0.789375
# [2000]	training's auc: 0.851452	valid_1's auc: 0.792295
# [3000]	training's auc: 0.873098	valid_1's auc: 0.793298
# Early stopping, best iteration is:
# [3195]	training's auc: 0.87687	valid_1's auc: 0.79352
# Fold  3 AUC : 0.793519
#
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.823127	valid_1's auc: 0.793225
# [2000]	training's auc: 0.850502	valid_1's auc: 0.79602
# Early stopping, best iteration is:
# [2705]	training's auc: 0.865986	valid_1's auc: 0.796678
# Fold  4 AUC : 0.796695
#
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.824638	valid_1's auc: 0.784576
# [2000]	training's auc: 0.851892	valid_1's auc: 0.787078
# [3000]	training's auc: 0.873723	valid_1's auc: 0.787875
# Early stopping, best iteration is:
# [3674]	training's auc: 0.886699	valid_1's auc: 0.788257
# Fold  5 AUC : 0.788251
#
# Full AUC score : 0.793015
# Elapsed time=3005.03 sec.

# %%
init_time = time.time()
kfold_lightgbm(test_df, 5, modeltype = 'gbdt', epoch = 5000)
print("Elapsed time={:5.2f} sec.".format(time.time() - init_time))
# Out:
# Starting LightGBM gbdt. Train shape: (307511, 798), test shape: (48744, 798)
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.82399	valid_1's auc: 0.792708
# [2000]	training's auc: 0.850088	valid_1's auc: 0.795056
# [3000]	training's auc: 0.870567	valid_1's auc: 0.795593
# Early stopping, best iteration is:
# [3085]	training's auc: 0.872162	valid_1's auc: 0.795667
# Fold  1 AUC : 0.795678
#
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.824284	valid_1's auc: 0.788063
# [2000]	training's auc: 0.850588	valid_1's auc: 0.790778
# [3000]	training's auc: 0.871504	valid_1's auc: 0.791444
# Early stopping, best iteration is:
# [3546]	training's auc: 0.881335	valid_1's auc: 0.791772
# Fold  2 AUC : 0.791771
#
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.824186	valid_1's auc: 0.789041
# [2000]	training's auc: 0.850698	valid_1's auc: 0.791928
# [3000]	training's auc: 0.871694	valid_1's auc: 0.792631
# Early stopping, best iteration is:
# [3204]	training's auc: 0.875537	valid_1's auc: 0.79276
# Fold  3 AUC : 0.792753
#
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.823422	valid_1's auc: 0.793224
# [2000]	training's auc: 0.849835	valid_1's auc: 0.796522
# Early stopping, best iteration is:
# [2642]	training's auc: 0.863699	valid_1's auc: 0.797087
# Fold  4 AUC : 0.797096
#
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.824711	valid_1's auc: 0.78497
# [2000]	training's auc: 0.851155	valid_1's auc: 0.787172
# Early stopping, best iteration is:
# [2685]	training's auc: 0.865829	valid_1's auc: 0.787633
# Fold  5 AUC : 0.787618
#
# Full AUC score : 0.792937
# Elapsed time=3237.37 sec.

# %% [markdown]
# ## boosting_type：goss

# %%
init_time = time.time()
kfold_lightgbm(final_df, 5, modeltype = 'goss', epoch = 5000)
print("Elapsed time={:5.2f} sec.".format(time.time() - init_time))
# Out:
# Starting LightGBM goss. Train shape: (307511, 932), test shape: (48744, 932)
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.826049	valid_1's auc: 0.793471
# [2000]	training's auc: 0.856739	valid_1's auc: 0.795816
# Early stopping, best iteration is:
# [2316]	training's auc: 0.864569	valid_1's auc: 0.796191
# Fold  1 AUC : 0.796179
#
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.826795	valid_1's auc: 0.78814
# [2000]	training's auc: 0.857476	valid_1's auc: 0.791316
# Early stopping, best iteration is:
# [2633]	training's auc: 0.872932	valid_1's auc: 0.791881
# Fold  2 AUC : 0.791874
#
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.825915	valid_1's auc: 0.789642
# [2000]	training's auc: 0.856793	valid_1's auc: 0.793003
# Early stopping, best iteration is:
# [2308]	training's auc: 0.864688	valid_1's auc: 0.79353
# Fold  3 AUC : 0.793541
#
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.825614	valid_1's auc: 0.794089
# [2000]	training's auc: 0.856243	valid_1's auc: 0.797427
# Early stopping, best iteration is:
# [2757]	training's auc: 0.874651	valid_1's auc: 0.798236
# Fold  4 AUC : 0.798245
#
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.827328	valid_1's auc: 0.784553
# [2000]	training's auc: 0.857897	valid_1's auc: 0.787538
# [3000]	training's auc: 0.880935	valid_1's auc: 0.788331
# Early stopping, best iteration is:
# [3183]	training's auc: 0.884822	valid_1's auc: 0.788464
# Fold  5 AUC : 0.788452
#
# Full AUC score : 0.793572
# Elapsed time=1630.83 sec.

# %%
init_time = time.time()
kfold_lightgbm(test_df, 5, modeltype = 'goss', epoch = 5000)
print("Elapsed time={:5.2f} sec.".format(time.time() - init_time))
# Out:
# Starting LightGBM goss. Train shape: (307511, 798), test shape: (48744, 798)
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.825563	valid_1's auc: 0.793763
# [2000]	training's auc: 0.854628	valid_1's auc: 0.796142
# Early stopping, best iteration is:
# [2733]	training's auc: 0.871335	valid_1's auc: 0.796563
# Fold  1 AUC : 0.796576
#
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.825978	valid_1's auc: 0.788935
# [2000]	training's auc: 0.855102	valid_1's auc: 0.791908
# Early stopping, best iteration is:
# [2512]	training's auc: 0.867196	valid_1's auc: 0.792268
# Fold  2 AUC : 0.792269
#
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.8259	valid_1's auc: 0.789635
# [2000]	training's auc: 0.85494	valid_1's auc: 0.793148
# [3000]	training's auc: 0.877436	valid_1's auc: 0.793994
# Early stopping, best iteration is:
# [3048]	training's auc: 0.878414	valid_1's auc: 0.794053
# Fold  3 AUC : 0.794066
#
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.82493	valid_1's auc: 0.793937
# [2000]	training's auc: 0.854214	valid_1's auc: 0.79722
# [3000]	training's auc: 0.876915	valid_1's auc: 0.798239
# Early stopping, best iteration is:
# [3525]	training's auc: 0.887056	valid_1's auc: 0.798569
# Fold  4 AUC : 0.798562
#
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.82655	valid_1's auc: 0.785177
# [2000]	training's auc: 0.855533	valid_1's auc: 0.788123
# [3000]	training's auc: 0.87776	valid_1's auc: 0.788755
# Early stopping, best iteration is:
# [3022]	training's auc: 0.878161	valid_1's auc: 0.788777
# Fold  5 AUC : 0.788770
#
# Full AUC score : 0.794003
# Elapsed time=2084.57 sec.

# %% [markdown]
# ## boosting_type：dart

# %%
init_time = time.time()
kfold_lightgbm(final_df, 5, modeltype = 'dart', epoch = 5000)
print("Elapsed time={:5.2f} sec.".format(time.time() - init_time))
# Out:
# Starting LightGBM dart. Train shape: (307511, 932), test shape: (48744, 932)
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.773744	valid_1's auc: 0.764442
# [2000]	training's auc: 0.801764	valid_1's auc: 0.782345
# [3000]	training's auc: 0.817426	valid_1's auc: 0.789251
# [4000]	training's auc: 0.830723	valid_1's auc: 0.792529
# [5000]	training's auc: 0.842823	valid_1's auc: 0.794676
# Did not meet early stopping. Best iteration is:
# [5000]	training's auc: 0.842823	valid_1's auc: 0.794676
# Fold  1 AUC : 0.794670
#
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.775499	valid_1's auc: 0.760305
# [2000]	training's auc: 0.802964	valid_1's auc: 0.778547
# [3000]	training's auc: 0.818251	valid_1's auc: 0.785531
# [4000]	training's auc: 0.831281	valid_1's auc: 0.789103
# [5000]	training's auc: 0.843275	valid_1's auc: 0.791158
# Did not meet early stopping. Best iteration is:
# [5000]	training's auc: 0.843275	valid_1's auc: 0.791158
# Fold  2 AUC : 0.791154
#
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.774556	valid_1's auc: 0.758392
# [2000]	training's auc: 0.802258	valid_1's auc: 0.778041
# [3000]	training's auc: 0.817472	valid_1's auc: 0.786089
# [4000]	training's auc: 0.830266	valid_1's auc: 0.790327
# [5000]	training's auc: 0.842417	valid_1's auc: 0.792027
# Did not meet early stopping. Best iteration is:
# [5000]	training's auc: 0.842417	valid_1's auc: 0.792027
# Fold  3 AUC : 0.792041
#
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.773682	valid_1's auc: 0.765681
# [2000]	training's auc: 0.801571	valid_1's auc: 0.783807
# [3000]	training's auc: 0.817051	valid_1's auc: 0.790753
# [4000]	training's auc: 0.830267	valid_1's auc: 0.794186
# [5000]	training's auc: 0.842212	valid_1's auc: 0.795945
# Did not meet early stopping. Best iteration is:
# [5000]	training's auc: 0.842212	valid_1's auc: 0.795945
# Fold  4 AUC : 0.795967
#
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.775742	valid_1's auc: 0.755454
# [2000]	training's auc: 0.803725	valid_1's auc: 0.774004
# [3000]	training's auc: 0.818813	valid_1's auc: 0.780669
# [4000]	training's auc: 0.831728	valid_1's auc: 0.7839
# [5000]	training's auc: 0.843509	valid_1's auc: 0.785897
# Did not meet early stopping. Best iteration is:
# [5000]	training's auc: 0.843509	valid_1's auc: 0.785897
# Fold  5 AUC : 0.785890
#
# Full AUC score : 0.791897
# Elapsed time=8775.35 sec.

# %%
init_time = time.time()
kfold_lightgbm(test_df, 5, modeltype = 'dart', epoch = 5000)
print("Elapsed time={:5.2f} sec.".format(time.time() - init_time))
# Out:
# Starting LightGBM dart. Train shape: (307511, 798), test shape: (48744, 798)
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.775449	valid_1's auc: 0.765543
# [2000]	training's auc: 0.802837	valid_1's auc: 0.783156
# [3000]	training's auc: 0.817948	valid_1's auc: 0.789769
# [4000]	training's auc: 0.830601	valid_1's auc: 0.793104
# [5000]	training's auc: 0.84199	valid_1's auc: 0.794769
# Did not meet early stopping. Best iteration is:
# [5000]	training's auc: 0.84199	valid_1's auc: 0.794769
# Fold  1 AUC : 0.794767
#
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.777091	valid_1's auc: 0.76191
# [2000]	training's auc: 0.804005	valid_1's auc: 0.779858
# [3000]	training's auc: 0.818698	valid_1's auc: 0.786399
# [4000]	training's auc: 0.831317	valid_1's auc: 0.789761
# [5000]	training's auc: 0.842849	valid_1's auc: 0.791684
# Did not meet early stopping. Best iteration is:
# [5000]	training's auc: 0.842849	valid_1's auc: 0.791684
# Fold  2 AUC : 0.791672
#
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.77641	valid_1's auc: 0.759698
# [2000]	training's auc: 0.803294	valid_1's auc: 0.778547
# [3000]	training's auc: 0.818006	valid_1's auc: 0.786432
# [4000]	training's auc: 0.830554	valid_1's auc: 0.790546
# [5000]	training's auc: 0.842238	valid_1's auc: 0.79224
# Did not meet early stopping. Best iteration is:
# [5000]	training's auc: 0.842238	valid_1's auc: 0.79224
# Fold  3 AUC : 0.792255
#
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.775398	valid_1's auc: 0.767067
# [2000]	training's auc: 0.802606	valid_1's auc: 0.78431
# [3000]	training's auc: 0.81753	valid_1's auc: 0.791453
# [4000]	training's auc: 0.829992	valid_1's auc: 0.79452
# [5000]	training's auc: 0.841686	valid_1's auc: 0.796044
# Did not meet early stopping. Best iteration is:
# [5000]	training's auc: 0.841686	valid_1's auc: 0.796044
# Fold  4 AUC : 0.796067
#
# Training until validation scores don't improve for 200 rounds.
# [1000]	training's auc: 0.77759	valid_1's auc: 0.756874
# [2000]	training's auc: 0.804716	valid_1's auc: 0.774541
# [3000]	training's auc: 0.819253	valid_1's auc: 0.781093
# [4000]	training's auc: 0.831693	valid_1's auc: 0.784542
# [5000]	training's auc: 0.842987	valid_1's auc: 0.786473
# Did not meet early stopping. Best iteration is:
# [5000]	training's auc: 0.842987	valid_1's auc: 0.786473
# Fold  5 AUC : 0.786451
#
# Full AUC score : 0.792206
# Elapsed time=8781.10 sec.

# %% [markdown]
# ## boosting_type：rf

# %%
init_time = time.time()
kfold_lightgbm(test_df, 5, modeltype = 'rf', epoch = 5000)
print("Elapsed time={:5.2f} sec.".format(time.time() - init_time))

# %%
init_time = time.time()
kfold_lightgbm(final_df, 5, modeltype = 'rf', epoch = 5000)
print("Elapsed time={:5.2f} sec.".format(time.time() - init_time))
# Out:
# Starting LightGBM rf. Train shape: (307511, 932), test shape: (48744, 932)
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [227]	training's auc: 0.7222	valid_1's auc: 0.720019
# Fold  1 AUC : 0.720019
#
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [208]	training's auc: 0.723575	valid_1's auc: 0.719657
# Fold  2 AUC : 0.719657
#
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [227]	training's auc: 0.724123	valid_1's auc: 0.713323
# Fold  3 AUC : 0.713323
#
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [31]	training's auc: 0.721529	valid_1's auc: 0.723186
# Fold  4 AUC : 0.723186
#
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [313]	training's auc: 0.724006	valid_1's auc: 0.715125
# Fold  5 AUC : 0.715125
#
# Full AUC score : 0.716943
# Elapsed time=520.88 sec.

# %%
init_time = time.time()
kfold_lightgbm(test_df, 5, modeltype = 'rf', epoch = 5000)
print("Elapsed time={:5.2f} sec.".format(time.time() - init_time))

# %% [markdown]
# # XGBoost 模型

# %%
from numba import cuda
cuda.select_device(0)
cuda.close()

# %%
import numpy as np
import pandas as pd
import gc
import time
from contextlib import contextmanager
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import KFold, StratifiedKFold
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import pickle

# %%
def kfold_xgb(df, num_folds, stratified = True, debug= False):
    # Divide in training/validation and test data
    train_df = df[df['TARGET'].notnull()]
    test_df = df[df['TARGET'].isnull()]
    print("Starting XGBoost. Train shape: {}, test shape: {}".format(train_df.shape, test_df.shape))
    del df
    gc.collect()
    # Cross validation model
    if stratified:
        folds = StratifiedKFold(n_splits= num_folds, shuffle=True, random_state=1001)
    else:
        folds = KFold(n_splits= num_folds, shuffle=True, random_state=1001)
    # Create arrays and dataframes to store results
    oof_preds = np.zeros(train_df.shape[0])
    sub_preds = np.zeros(test_df.shape[0])
    feature_importance_df = pd.DataFrame()
    feats = [f for f in train_df.columns if f not in ['TARGET','SK_ID_CURR','SK_ID_BUREAU','SK_ID_PREV','index']]
    
    for n_fold, (train_idx, valid_idx) in enumerate(folds.split(train_df[feats], train_df['TARGET'])):
        #if n_fold == 0: # REmove for full K-fold run
        train_x, train_y = train_df[feats].iloc[train_idx], train_df['TARGET'].iloc[train_idx]
        valid_x, valid_y = train_df[feats].iloc[valid_idx], train_df['TARGET'].iloc[valid_idx]

        clf = XGBClassifier(learning_rate =0.01, 
                            n_estimators=5000, 
                            max_depth=4, 
                            min_child_weight=5,
#                             tree_method='gpu_hist',
                            subsample=0.8, 
                            colsample_bytree=0.8, 
                            objective= 'binary:logistic',
                            nthread=4,
                            scale_pos_weight=2.5,
                            seed=28,
                            reg_lambda = 1.2)
        
        
        clf.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], 
            eval_metric= 'auc', verbose= 1000, early_stopping_rounds= 200)
        
        
        oof_preds[valid_idx] = clf.predict_proba(valid_x)[:, 1]
        sub_preds += clf.predict_proba(test_df[feats])[:, 1] # / folds.n_splits # - Uncomment for K-fold 

        fold_importance_df = pd.DataFrame()
        fold_importance_df["feature"] = feats
        fold_importance_df["importance"] = clf.feature_importances_
        fold_importance_df["fold"] = n_fold + 1
        feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
        print('Fold %2d AUC : %.6f' % (n_fold + 1, roc_auc_score(valid_y, oof_preds[valid_idx])))
        del clf, train_x, train_y, valid_x, valid_y
        gc.collect()

        np.save("xgb_oof_preds_1", oof_preds)
        np.save("xgb_sub_preds_1", sub_preds)
        
    
    # print('Full AUC score %.6f' % roc_auc_score(train_df['TARGET'], oof_preds))
    # Write submission file and plot feature importance
    if not debug:
        test_df['TARGET'] = sub_preds
        test_df[['SK_ID_CURR', 'TARGET']].to_csv('submission_XGBoost.csv', index= False)
    #display_importances(feature_importance_df)
    #return feature_importance_df

# Display/plot feature importance
def display_importances(feature_importance_df_):
    cols = feature_importance_df_[["feature", "importance"]].groupby("feature").mean().sort_values(by="importance", ascending=False)[:40].index
    best_features = feature_importance_df_.loc[feature_importance_df_.feature.isin(cols)]
    plt.figure(figsize=(8, 10))
    sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False))
    plt.title('XGBoost Features (avg over folds)')
    plt.tight_layout()
    plt.savefig('xgb_importances02.png')

# %%
init_time = time.time()
kfold_xgb(test_df, 5)
print("Elapsed time={:5.2f} sec.".format(time.time() - init_time))
# Out:
# Starting XGBoost. Train shape: (307511, 798), test shape: (48744, 798)
# [0]	validation_0-auc:0.702419	validation_1-auc:0.698361
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 200 rounds.
# [1000]	validation_0-auc:0.804332	validation_1-auc:0.786172
# [2000]	validation_0-auc:0.82644	validation_1-auc:0.793158
# [3000]	validation_0-auc:0.841588	validation_1-auc:0.795423
# [4000]	validation_0-auc:0.854178	validation_1-auc:0.796253
# [4999]	validation_0-auc:0.865362	validation_1-auc:0.796573
# Fold  1 AUC : 0.796600
# [0]	validation_0-auc:0.70398	validation_1-auc:0.701408
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 200 rounds.
# [1000]	validation_0-auc:0.805494	validation_1-auc:0.781308
# [2000]	validation_0-auc:0.826709	validation_1-auc:0.788497
# [3000]	validation_0-auc:0.841767	validation_1-auc:0.791127
# [4000]	validation_0-auc:0.854412	validation_1-auc:0.792243
# [4999]	validation_0-auc:0.865627	validation_1-auc:0.79285
# Fold  2 AUC : 0.792859
# [0]	validation_0-auc:0.705327	validation_1-auc:0.695004
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 200 rounds.
# [1000]	validation_0-auc:0.80487	validation_1-auc:0.780084
# [2000]	validation_0-auc:0.826506	validation_1-auc:0.788487
# [3000]	validation_0-auc:0.841446	validation_1-auc:0.791212
# [4000]	validation_0-auc:0.853771	validation_1-auc:0.792449
# [4999]	validation_0-auc:0.864697	validation_1-auc:0.793393
# Fold  3 AUC : 0.793401
# [0]	validation_0-auc:0.701852	validation_1-auc:0.701522
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 200 rounds.
# [1000]	validation_0-auc:0.804109	validation_1-auc:0.786774
# [2000]	validation_0-auc:0.825943	validation_1-auc:0.794362
# [3000]	validation_0-auc:0.840727	validation_1-auc:0.796804
# [4000]	validation_0-auc:0.853432	validation_1-auc:0.797937
# [4999]	validation_0-auc:0.864467	validation_1-auc:0.798775
# Fold  4 AUC : 0.798811
# [0]	validation_0-auc:0.704244	validation_1-auc:0.695507
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 200 rounds.
# [1000]	validation_0-auc:0.80591	validation_1-auc:0.777448
# [2000]	validation_0-auc:0.827213	validation_1-auc:0.78407
# [3000]	validation_0-auc:0.842297	validation_1-auc:0.786779
# [4000]	validation_0-auc:0.855003	validation_1-auc:0.787985
# [4999]	validation_0-auc:0.866199	validation_1-auc:0.78862
# Fold  5 AUC : 0.788622
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Elapsed time=58553.60 sec.

# %%
init_time = time.time()
kfold_xgb(final_df, 5)
print("Elapsed time={:5.2f} sec.".format(time.time() - init_time))
# Out:
# Starting XGBoost. Train shape: (307507, 871), test shape: (48744, 871)
# [0]	validation_0-auc:0.72139	validation_1-auc:0.719406
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 200 rounds.
# [1000]	validation_0-auc:0.801304	validation_1-auc:0.782099
# [2000]	validation_0-auc:0.824016	validation_1-auc:0.788724
# [3000]	validation_0-auc:0.840526	validation_1-auc:0.790976
# [4000]	validation_0-auc:0.853685	validation_1-auc:0.791867
# [4999]	validation_0-auc:0.865639	validation_1-auc:0.792425
# Fold  1 AUC : 0.792440
# [0]	validation_0-auc:0.722441	validation_1-auc:0.714728
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 200 rounds.
# [1000]	validation_0-auc:0.802008	validation_1-auc:0.778002
# [2000]	validation_0-auc:0.824956	validation_1-auc:0.78592
# [3000]	validation_0-auc:0.841242	validation_1-auc:0.788808
# [4000]	validation_0-auc:0.854325	validation_1-auc:0.790029
# [4999]	validation_0-auc:0.86594	validation_1-auc:0.791041
# Fold  2 AUC : 0.791055
# [0]	validation_0-auc:0.719852	validation_1-auc:0.718669
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 200 rounds.
# [1000]	validation_0-auc:0.800868	validation_1-auc:0.784492
# [2000]	validation_0-auc:0.824192	validation_1-auc:0.791901
# [3000]	validation_0-auc:0.840714	validation_1-auc:0.79441
# [4000]	validation_0-auc:0.854098	validation_1-auc:0.795287
# [4999]	validation_0-auc:0.865842	validation_1-auc:0.79588
# Fold  3 AUC : 0.795930
# [0]	validation_0-auc:0.720782	validation_1-auc:0.715196
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 200 rounds.
# [1000]	validation_0-auc:0.801909	validation_1-auc:0.777854
# [2000]	validation_0-auc:0.824753	validation_1-auc:0.785708
# [3000]	validation_0-auc:0.840976	validation_1-auc:0.78853
# [4000]	validation_0-auc:0.854492	validation_1-auc:0.789926
# [4999]	validation_0-auc:0.866383	validation_1-auc:0.790833
# Fold  4 AUC : 0.790833
# [0]	validation_0-auc:0.720827	validation_1-auc:0.71553
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 200 rounds.
# [1000]	validation_0-auc:0.802419	validation_1-auc:0.775984
# [2000]	validation_0-auc:0.825096	validation_1-auc:0.783317
# [3000]	validation_0-auc:0.841151	validation_1-auc:0.785912
# [4000]	validation_0-auc:0.854236	validation_1-auc:0.787287
# [4999]	validation_0-auc:0.865872	validation_1-auc:0.788194
# Fold  5 AUC : 0.788199
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Elapsed time=62182.09 sec.
