# %% [markdown]
# This is based on 'bear_Final_model' released 2020/01/23

# %%
# Forked from excellent kernel : https://www.kaggle.com/jsaguiar/updated-0-792-lb-lightgbm-with-simple-features
# From Kaggler : https://www.kaggle.com/jsaguiar
# Just added a few features so I thought I had to make release it as well...

import numpy as np
import pandas as pd
import gc
import time
from contextlib import contextmanager
import lightgbm as lgb
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import KFold, StratifiedKFold
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import csv

# %%
# Reading the saved dtypes Series
final_df_dtypes = \
pd.read_csv('../../../BDSE12-Group3/datasets/homecdt_ss_output/ss_fteng_fromBDSE12_03G_HomeCredit_V1_20200201b_dtypes_series.csv'\
            , header=None, index_col=0, squeeze=True)
del final_df_dtypes.index.name
final_df_dtypes = final_df_dtypes.to_dict()
final_df_dtypes
# Out:
# {'SK_ID_CURR': 'uint32',
#  'AMT_REQ_CREDIT_BUREAU_DAY_1.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_DAY_2.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_DAY_3.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_DAY_4.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_DAY_5.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_DAY_6.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_DAY_8.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_DAY_9.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_HOUR_1.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_HOUR_2.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_HOUR_3.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_HOUR_4.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_MON_1.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_MON_10.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_MON_11.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_MON_12.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_MON_13.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_MON_14.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_MON_15.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_MON_16.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_MON_17.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_MON_18.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_MON_19.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_MON_2.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_MON_22.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_MON_23.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_MON_24.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_MON_27.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_MON_3.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_MON_4.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_MON_5.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_MON_6.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_MON_7.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_MON_8.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_MON_9.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_QRT_1.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_QRT_19.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_QRT_2.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_QRT_261.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_QRT_3.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_QRT_4.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_QRT_5.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_QRT_6.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_QRT_7.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_QRT_8.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_WEEK_1.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_WEEK_2.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_WEEK_3.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_WEEK_4.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_WEEK_5.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_WEEK_6.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_WEEK_7.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_WEEK_8.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_YEAR_1.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_YEAR_10.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_YEAR_11.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_YEAR_12.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_YEAR_13.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_YEAR_14.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_YEAR_15.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_YEAR_16.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_YEAR_17.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_YEAR_18.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_YEAR_19.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_YEAR_2.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_YEAR_20.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_YEAR_21.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_YEAR_22.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_YEAR_23.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_YEAR_25.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_YEAR_3.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_YEAR_4.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_YEAR_5.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_YEAR_6.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_YEAR_7.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_YEAR_8.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_YEAR_9.0': 'uint8',
#  'CNT_CHILDREN_1': 'uint8',
#  'CNT_CHILDREN_10': 'uint8',
#  'CNT_CHILDREN_11': 'uint8',
#  'CNT_CHILDREN_12': 'uint8',
#  'CNT_CHILDREN_14': 'uint8',
#  'CNT_CHILDREN_19': 'uint8',
#  'CNT_CHILDREN_2': 'uint8',
#  'CNT_CHILDREN_20': 'uint8',
#  'CNT_CHILDREN_3': 'uint8',
#  'CNT_CHILDREN_4': 'uint8',
#  'CNT_CHILDREN_5': 'uint8',
#  'CNT_CHILDREN_6': 'uint8',
#  'CNT_CHILDREN_7': 'uint8',
#  'CNT_CHILDREN_8': 'uint8',
#  'CNT_CHILDREN_9': 'uint8',
#  'CNT_FAM_MEMBERS_10.0': 'uint8',
#  'CNT_FAM_MEMBERS_11.0': 'uint8',
#  'CNT_FAM_MEMBERS_12.0': 'uint8',
#  'CNT_FAM_MEMBERS_13.0': 'uint8',
#  'CNT_FAM_MEMBERS_14.0': 'uint8',
#  'CNT_FAM_MEMBERS_15.0': 'uint8',
#  'CNT_FAM_MEMBERS_16.0': 'uint8',
#  'CNT_FAM_MEMBERS_2.0': 'uint8',
#  'CNT_FAM_MEMBERS_20.0': 'uint8',
#  'CNT_FAM_MEMBERS_21.0': 'uint8',
#  'CNT_FAM_MEMBERS_3.0': 'uint8',
#  'CNT_FAM_MEMBERS_4.0': 'uint8',
#  'CNT_FAM_MEMBERS_5.0': 'uint8',
#  'CNT_FAM_MEMBERS_6.0': 'uint8',
#  'CNT_FAM_MEMBERS_7.0': 'uint8',
#  'CNT_FAM_MEMBERS_8.0': 'uint8',
#  'CNT_FAM_MEMBERS_9.0': 'uint8',
#  'CODE_GENDER_M': 'uint8',
#  'CODE_GENDER_XNA': 'uint8',
#  'DEF_30_CNT_SOCIAL_CIRCLE_1.0': 'uint8',
#  'DEF_30_CNT_SOCIAL_CIRCLE_2.0': 'uint8',
#  'DEF_30_CNT_SOCIAL_CIRCLE_3.0': 'uint8',
#  'DEF_30_CNT_SOCIAL_CIRCLE_34.0': 'uint8',
#  'DEF_30_CNT_SOCIAL_CIRCLE_4.0': 'uint8',
#  'DEF_30_CNT_SOCIAL_CIRCLE_5.0': 'uint8',
#  'DEF_30_CNT_SOCIAL_CIRCLE_6.0': 'uint8',
#  'DEF_30_CNT_SOCIAL_CIRCLE_7.0': 'uint8',
#  'DEF_30_CNT_SOCIAL_CIRCLE_8.0': 'uint8',
#  'DEF_60_CNT_SOCIAL_CIRCLE_1.0': 'uint8',
#  'DEF_60_CNT_SOCIAL_CIRCLE_2.0': 'uint8',
#  'DEF_60_CNT_SOCIAL_CIRCLE_24.0': 'uint8',
#  'DEF_60_CNT_SOCIAL_CIRCLE_3.0': 'uint8',
#  'DEF_60_CNT_SOCIAL_CIRCLE_4.0': 'uint8',
#  'DEF_60_CNT_SOCIAL_CIRCLE_5.0': 'uint8',
#  'DEF_60_CNT_SOCIAL_CIRCLE_6.0': 'uint8',
#  'DEF_60_CNT_SOCIAL_CIRCLE_7.0': 'uint8',
#  'ELEVATORS_MEDI_0.02': 'uint8',
#  'ELEVATORS_MEDI_0.04': 'uint8',
#  'ELEVATORS_MEDI_0.06': 'uint8',
#  'ELEVATORS_MEDI_0.08': 'uint8',
#  'ELEVATORS_MEDI_0.1': 'uint8',
#  'ELEVATORS_MEDI_0.12': 'uint8',
#  'ELEVATORS_MEDI_0.14': 'uint8',
#  'ELEVATORS_MEDI_0.16': 'uint8',
#  'ELEVATORS_MEDI_0.18': 'uint8',
#  'ELEVATORS_MEDI_0.2': 'uint8',
#  'ELEVATORS_MEDI_0.22': 'uint8',
#  'ELEVATORS_MEDI_0.24': 'uint8',
#  'ELEVATORS_MEDI_0.26': 'uint8',
#  'ELEVATORS_MEDI_0.28': 'uint8',
#  'ELEVATORS_MEDI_0.3': 'uint8',
#  'ELEVATORS_MEDI_0.32': 'uint8',
#  'ELEVATORS_MEDI_0.34': 'uint8',
#  'ELEVATORS_MEDI_0.36': 'uint8',
#  'ELEVATORS_MEDI_0.38': 'uint8',
#  'ELEVATORS_MEDI_0.4': 'uint8',
#  'ELEVATORS_MEDI_0.42': 'uint8',
#  'ELEVATORS_MEDI_0.44': 'uint8',
#  'ELEVATORS_MEDI_0.46': 'uint8',
#  'ELEVATORS_MEDI_0.48': 'uint8',
#  'ELEVATORS_MEDI_0.5': 'uint8',
#  'ELEVATORS_MEDI_0.52': 'uint8',
#  'ELEVATORS_MEDI_0.54': 'uint8',
#  'ELEVATORS_MEDI_0.56': 'uint8',
#  'ELEVATORS_MEDI_0.58': 'uint8',
#  'ELEVATORS_MEDI_0.6': 'uint8',
#  'ELEVATORS_MEDI_0.62': 'uint8',
#  'ELEVATORS_MEDI_0.64': 'uint8',
#  'ELEVATORS_MEDI_0.66': 'uint8',
#  'ELEVATORS_MEDI_0.68': 'uint8',
#  'ELEVATORS_MEDI_0.72': 'uint8',
#  'ELEVATORS_MEDI_0.74': 'uint8',
#  'ELEVATORS_MEDI_0.76': 'uint8',
#  'ELEVATORS_MEDI_0.78': 'uint8',
#  'ELEVATORS_MEDI_0.8': 'uint8',
#  'ELEVATORS_MEDI_0.84': 'uint8',
#  'ELEVATORS_MEDI_0.88': 'uint8',
#  'ELEVATORS_MEDI_0.9': 'uint8',
#  'ELEVATORS_MEDI_0.92': 'uint8',
#  'ELEVATORS_MEDI_0.96': 'uint8',
#  'ELEVATORS_MEDI_1.0': 'uint8',
#  'ELEVATORS_MODE_0.0403': 'uint8',
#  'ELEVATORS_MODE_0.0806': 'uint8',
#  'ELEVATORS_MODE_0.1208': 'uint8',
#  'ELEVATORS_MODE_0.1611': 'uint8',
#  'ELEVATORS_MODE_0.2014': 'uint8',
#  'ELEVATORS_MODE_0.2417': 'uint8',
#  'ELEVATORS_MODE_0.282': 'uint8',
#  'ELEVATORS_MODE_0.3222': 'uint8',
#  'ELEVATORS_MODE_0.3625': 'uint8',
#  'ELEVATORS_MODE_0.4028': 'uint8',
#  'ELEVATORS_MODE_0.4431': 'uint8',
#  'ELEVATORS_MODE_0.4834': 'uint8',
#  'ELEVATORS_MODE_0.5236': 'uint8',
#  'ELEVATORS_MODE_0.5639': 'uint8',
#  'ELEVATORS_MODE_0.6042': 'uint8',
#  'ELEVATORS_MODE_0.6445': 'uint8',
#  'ELEVATORS_MODE_0.6848': 'uint8',
#  'ELEVATORS_MODE_0.725': 'uint8',
#  'ELEVATORS_MODE_0.7653': 'uint8',
#  'ELEVATORS_MODE_0.8056': 'uint8',
#  'ELEVATORS_MODE_0.8459': 'uint8',
#  'ELEVATORS_MODE_0.8862': 'uint8',
#  'ELEVATORS_MODE_0.9264': 'uint8',
#  'ELEVATORS_MODE_0.9667': 'uint8',
#  'ELEVATORS_MODE_1.0': 'uint8',
#  'EMERGENCYSTATE_MODE_Yes': 'uint8',
#  'EMERGENCYSTATE_MODE_nan': 'uint8',
#  'ENTRANCES_MEDI_0.0172': 'uint8',
#  'ENTRANCES_MEDI_0.0345': 'uint8',
#  'ENTRANCES_MEDI_0.0517': 'uint8',
#  'ENTRANCES_MEDI_0.069': 'uint8',
#  'ENTRANCES_MEDI_0.0862': 'uint8',
#  'ENTRANCES_MEDI_0.1034': 'uint8',
#  'ENTRANCES_MEDI_0.1207': 'uint8',
#  'ENTRANCES_MEDI_0.1379': 'uint8',
#  'ENTRANCES_MEDI_0.1552': 'uint8',
#  'ENTRANCES_MEDI_0.1724': 'uint8',
#  'ENTRANCES_MEDI_0.1897': 'uint8',
#  'ENTRANCES_MEDI_0.2069': 'uint8',
#  'ENTRANCES_MEDI_0.2241': 'uint8',
#  'ENTRANCES_MEDI_0.2414': 'uint8',
#  'ENTRANCES_MEDI_0.2586': 'uint8',
#  'ENTRANCES_MEDI_0.2759': 'uint8',
#  'ENTRANCES_MEDI_0.2931': 'uint8',
#  'ENTRANCES_MEDI_0.3103': 'uint8',
#  'ENTRANCES_MEDI_0.3276': 'uint8',
#  'ENTRANCES_MEDI_0.3448': 'uint8',
#  'ENTRANCES_MEDI_0.3621': 'uint8',
#  'ENTRANCES_MEDI_0.3793': 'uint8',
#  'ENTRANCES_MEDI_0.3966': 'uint8',
#  'ENTRANCES_MEDI_0.4138': 'uint8',
#  'ENTRANCES_MEDI_0.431': 'uint8',
#  'ENTRANCES_MEDI_0.4483': 'uint8',
#  'ENTRANCES_MEDI_0.4655': 'uint8',
#  'ENTRANCES_MEDI_0.4828': 'uint8',
#  'ENTRANCES_MEDI_0.5': 'uint8',
#  'ENTRANCES_MEDI_0.5172': 'uint8',
#  'ENTRANCES_MEDI_0.5517': 'uint8',
#  'ENTRANCES_MEDI_0.569': 'uint8',
#  'ENTRANCES_MEDI_0.5862': 'uint8',
#  'ENTRANCES_MEDI_0.6207': 'uint8',
#  'ENTRANCES_MEDI_0.6552': 'uint8',
#  'ENTRANCES_MEDI_0.6897': 'uint8',
#  'ENTRANCES_MEDI_0.7241': 'uint8',
#  'ENTRANCES_MEDI_0.7586': 'uint8',
#  'ENTRANCES_MEDI_0.7931': 'uint8',
#  'ENTRANCES_MEDI_0.8276': 'uint8',
#  'ENTRANCES_MEDI_0.8621': 'uint8',
#  'ENTRANCES_MEDI_0.8966': 'uint8',
#  'ENTRANCES_MEDI_0.931': 'uint8',
#  'ENTRANCES_MEDI_0.9655': 'uint8',
#  'ENTRANCES_MEDI_1.0': 'uint8',
#  'ENTRANCES_MODE_0.0345': 'uint8',
#  'ENTRANCES_MODE_0.069': 'uint8',
#  'ENTRANCES_MODE_0.1034': 'uint8',
#  'ENTRANCES_MODE_0.1379': 'uint8',
#  'ENTRANCES_MODE_0.1724': 'uint8',
#  'ENTRANCES_MODE_0.2069': 'uint8',
#  'ENTRANCES_MODE_0.2414': 'uint8',
#  'ENTRANCES_MODE_0.2759': 'uint8',
#  'ENTRANCES_MODE_0.3103': 'uint8',
#  'ENTRANCES_MODE_0.3448': 'uint8',
#  'ENTRANCES_MODE_0.3793': 'uint8',
#  'ENTRANCES_MODE_0.4138': 'uint8',
#  'ENTRANCES_MODE_0.4483': 'uint8',
#  'ENTRANCES_MODE_0.4828': 'uint8',
#  'ENTRANCES_MODE_0.5172': 'uint8',
#  'ENTRANCES_MODE_0.5517': 'uint8',
#  'ENTRANCES_MODE_0.5862': 'uint8',
#  'ENTRANCES_MODE_0.6207': 'uint8',
#  'ENTRANCES_MODE_0.6552': 'uint8',
#  'ENTRANCES_MODE_0.6897': 'uint8',
#  'ENTRANCES_MODE_0.7241': 'uint8',
#  'ENTRANCES_MODE_0.7586': 'uint8',
#  'ENTRANCES_MODE_0.7931': 'uint8',
#  'ENTRANCES_MODE_0.8276': 'uint8',
#  'ENTRANCES_MODE_0.8621': 'uint8',
#  'ENTRANCES_MODE_0.8966': 'uint8',
#  'ENTRANCES_MODE_0.931': 'uint8',
#  'ENTRANCES_MODE_0.9655': 'uint8',
#  'ENTRANCES_MODE_1.0': 'uint8',
#  'FLAG_CONT_MOBILE_1': 'uint8',
#  'FLAG_DOCUMENT_10_1': 'uint8',
#  'FLAG_DOCUMENT_11_1': 'uint8',
#  'FLAG_DOCUMENT_12_1': 'uint8',
#  'FLAG_DOCUMENT_13_1': 'uint8',
#  'FLAG_DOCUMENT_14_1': 'uint8',
#  'FLAG_DOCUMENT_15_1': 'uint8',
#  'FLAG_DOCUMENT_16_1': 'uint8',
#  'FLAG_DOCUMENT_17_1': 'uint8',
#  'FLAG_DOCUMENT_18_1': 'uint8',
#  'FLAG_DOCUMENT_19_1': 'uint8',
#  'FLAG_DOCUMENT_2_1': 'uint8',
#  'FLAG_DOCUMENT_20_1': 'uint8',
#  'FLAG_DOCUMENT_21_1': 'uint8',
#  'FLAG_DOCUMENT_3_1': 'uint8',
#  'FLAG_DOCUMENT_4_1': 'uint8',
#  'FLAG_DOCUMENT_5_1': 'uint8',
#  'FLAG_DOCUMENT_6_1': 'uint8',
#  'FLAG_DOCUMENT_7_1': 'uint8',
#  'FLAG_DOCUMENT_8_1': 'uint8',
#  'FLAG_DOCUMENT_9_1': 'uint8',
#  'FLAG_EMAIL_1': 'uint8',
#  'FLAG_EMP_PHONE_1': 'uint8',
#  'FLAG_MOBIL_1': 'uint8',
#  'FLAG_OWN_CAR_Y': 'uint8',
#  'FLAG_OWN_REALTY_Y': 'uint8',
#  'FLAG_PHONE_1': 'uint8',
#  'FLAG_WORK_PHONE_1': 'uint8',
#  'FLOORSMAX_MEDI_0.0208': 'uint8',
#  'FLOORSMAX_MEDI_0.0417': 'uint8',
#  'FLOORSMAX_MEDI_0.0625': 'uint8',
#  'FLOORSMAX_MEDI_0.0833': 'uint8',
#  'FLOORSMAX_MEDI_0.1042': 'uint8',
#  'FLOORSMAX_MEDI_0.125': 'uint8',
#  'FLOORSMAX_MEDI_0.1458': 'uint8',
#  'FLOORSMAX_MEDI_0.1667': 'uint8',
#  'FLOORSMAX_MEDI_0.1875': 'uint8',
#  'FLOORSMAX_MEDI_0.2083': 'uint8',
#  'FLOORSMAX_MEDI_0.2292': 'uint8',
#  'FLOORSMAX_MEDI_0.25': 'uint8',
#  'FLOORSMAX_MEDI_0.2708': 'uint8',
#  'FLOORSMAX_MEDI_0.2917': 'uint8',
#  'FLOORSMAX_MEDI_0.3125': 'uint8',
#  'FLOORSMAX_MEDI_0.3333': 'uint8',
#  'FLOORSMAX_MEDI_0.3542': 'uint8',
#  'FLOORSMAX_MEDI_0.375': 'uint8',
#  'FLOORSMAX_MEDI_0.3958': 'uint8',
#  'FLOORSMAX_MEDI_0.4167': 'uint8',
#  'FLOORSMAX_MEDI_0.4375': 'uint8',
#  'FLOORSMAX_MEDI_0.4583': 'uint8',
#  'FLOORSMAX_MEDI_0.4792': 'uint8',
#  'FLOORSMAX_MEDI_0.5': 'uint8',
#  'FLOORSMAX_MEDI_0.5208': 'uint8',
#  'FLOORSMAX_MEDI_0.5417': 'uint8',
#  'FLOORSMAX_MEDI_0.5625': 'uint8',
#  'FLOORSMAX_MEDI_0.5833': 'uint8',
#  'FLOORSMAX_MEDI_0.6042': 'uint8',
#  'FLOORSMAX_MEDI_0.625': 'uint8',
#  'FLOORSMAX_MEDI_0.6458': 'uint8',
#  'FLOORSMAX_MEDI_0.6667': 'uint8',
#  'FLOORSMAX_MEDI_0.6875': 'uint8',
#  'FLOORSMAX_MEDI_0.7083': 'uint8',
#  'FLOORSMAX_MEDI_0.7292': 'uint8',
#  'FLOORSMAX_MEDI_0.75': 'uint8',
#  'FLOORSMAX_MEDI_0.7708': 'uint8',
#  'FLOORSMAX_MEDI_0.7917': 'uint8',
#  'FLOORSMAX_MEDI_0.8125': 'uint8',
#  'FLOORSMAX_MEDI_0.8333': 'uint8',
#  'FLOORSMAX_MEDI_0.8542': 'uint8',
#  'FLOORSMAX_MEDI_0.875': 'uint8',
#  'FLOORSMAX_MEDI_0.8958': 'uint8',
#  'FLOORSMAX_MEDI_0.9167': 'uint8',
#  'FLOORSMAX_MEDI_0.9375': 'uint8',
#  'FLOORSMAX_MEDI_0.9583': 'uint8',
#  'FLOORSMAX_MEDI_0.9792': 'uint8',
#  'FLOORSMAX_MEDI_1.0': 'uint8',
#  'FLOORSMAX_MODE_0.0417': 'uint8',
#  'FLOORSMAX_MODE_0.0833': 'uint8',
#  'FLOORSMAX_MODE_0.125': 'uint8',
#  'FLOORSMAX_MODE_0.1667': 'uint8',
#  'FLOORSMAX_MODE_0.2083': 'uint8',
#  'FLOORSMAX_MODE_0.25': 'uint8',
#  'FLOORSMAX_MODE_0.2917': 'uint8',
#  'FLOORSMAX_MODE_0.3333': 'uint8',
#  'FLOORSMAX_MODE_0.375': 'uint8',
#  'FLOORSMAX_MODE_0.4167': 'uint8',
#  'FLOORSMAX_MODE_0.4583': 'uint8',
#  'FLOORSMAX_MODE_0.5': 'uint8',
#  'FLOORSMAX_MODE_0.5417': 'uint8',
#  'FLOORSMAX_MODE_0.5833': 'uint8',
#  'FLOORSMAX_MODE_0.625': 'uint8',
#  'FLOORSMAX_MODE_0.6667': 'uint8',
#  'FLOORSMAX_MODE_0.7083': 'uint8',
#  'FLOORSMAX_MODE_0.75': 'uint8',
#  'FLOORSMAX_MODE_0.7917': 'uint8',
#  'FLOORSMAX_MODE_0.8333': 'uint8',
#  'FLOORSMAX_MODE_0.875': 'uint8',
#  'FLOORSMAX_MODE_0.9167': 'uint8',
#  'FLOORSMAX_MODE_0.9583': 'uint8',
#  'FLOORSMAX_MODE_1.0': 'uint8',
#  'FLOORSMIN_MEDI_0.0208': 'uint8',
#  'FLOORSMIN_MEDI_0.0417': 'uint8',
#  'FLOORSMIN_MEDI_0.0625': 'uint8',
#  'FLOORSMIN_MEDI_0.0833': 'uint8',
#  'FLOORSMIN_MEDI_0.1042': 'uint8',
#  'FLOORSMIN_MEDI_0.125': 'uint8',
#  'FLOORSMIN_MEDI_0.1458': 'uint8',
#  'FLOORSMIN_MEDI_0.1667': 'uint8',
#  'FLOORSMIN_MEDI_0.1875': 'uint8',
#  'FLOORSMIN_MEDI_0.2083': 'uint8',
#  'FLOORSMIN_MEDI_0.2292': 'uint8',
#  'FLOORSMIN_MEDI_0.25': 'uint8',
#  'FLOORSMIN_MEDI_0.2708': 'uint8',
#  'FLOORSMIN_MEDI_0.2917': 'uint8',
#  'FLOORSMIN_MEDI_0.3125': 'uint8',
#  'FLOORSMIN_MEDI_0.3333': 'uint8',
#  'FLOORSMIN_MEDI_0.3542': 'uint8',
#  'FLOORSMIN_MEDI_0.375': 'uint8',
#  'FLOORSMIN_MEDI_0.3958': 'uint8',
#  'FLOORSMIN_MEDI_0.4167': 'uint8',
#  'FLOORSMIN_MEDI_0.4375': 'uint8',
#  'FLOORSMIN_MEDI_0.4583': 'uint8',
#  'FLOORSMIN_MEDI_0.4792': 'uint8',
#  'FLOORSMIN_MEDI_0.5': 'uint8',
#  'FLOORSMIN_MEDI_0.5208': 'uint8',
#  'FLOORSMIN_MEDI_0.5417': 'uint8',
#  'FLOORSMIN_MEDI_0.5625': 'uint8',
#  'FLOORSMIN_MEDI_0.5833': 'uint8',
#  'FLOORSMIN_MEDI_0.6042': 'uint8',
#  'FLOORSMIN_MEDI_0.625': 'uint8',
#  'FLOORSMIN_MEDI_0.6458': 'uint8',
#  'FLOORSMIN_MEDI_0.6667': 'uint8',
#  'FLOORSMIN_MEDI_0.6875': 'uint8',
#  'FLOORSMIN_MEDI_0.7083': 'uint8',
#  'FLOORSMIN_MEDI_0.7292': 'uint8',
#  'FLOORSMIN_MEDI_0.75': 'uint8',
#  'FLOORSMIN_MEDI_0.7708': 'uint8',
#  'FLOORSMIN_MEDI_0.7917': 'uint8',
#  'FLOORSMIN_MEDI_0.8125': 'uint8',
#  'FLOORSMIN_MEDI_0.8333': 'uint8',
#  'FLOORSMIN_MEDI_0.8542': 'uint8',
#  'FLOORSMIN_MEDI_0.875': 'uint8',
#  'FLOORSMIN_MEDI_0.9167': 'uint8',
#  'FLOORSMIN_MEDI_0.9583': 'uint8',
#  'FLOORSMIN_MEDI_0.9792': 'uint8',
#  'FLOORSMIN_MEDI_1.0': 'uint8',
#  'FLOORSMIN_MODE_0.0417': 'uint8',
#  'FLOORSMIN_MODE_0.0833': 'uint8',
#  'FLOORSMIN_MODE_0.125': 'uint8',
#  'FLOORSMIN_MODE_0.1667': 'uint8',
#  'FLOORSMIN_MODE_0.2083': 'uint8',
#  'FLOORSMIN_MODE_0.25': 'uint8',
#  'FLOORSMIN_MODE_0.2917': 'uint8',
#  'FLOORSMIN_MODE_0.3333': 'uint8',
#  'FLOORSMIN_MODE_0.375': 'uint8',
#  'FLOORSMIN_MODE_0.4167': 'uint8',
#  'FLOORSMIN_MODE_0.4583': 'uint8',
#  'FLOORSMIN_MODE_0.5': 'uint8',
#  'FLOORSMIN_MODE_0.5417': 'uint8',
#  'FLOORSMIN_MODE_0.5833': 'uint8',
#  'FLOORSMIN_MODE_0.625': 'uint8',
#  'FLOORSMIN_MODE_0.6667': 'uint8',
#  'FLOORSMIN_MODE_0.7083': 'uint8',
#  'FLOORSMIN_MODE_0.75': 'uint8',
#  'FLOORSMIN_MODE_0.7917': 'uint8',
#  'FLOORSMIN_MODE_0.8333': 'uint8',
#  'FLOORSMIN_MODE_0.875': 'uint8',
#  'FLOORSMIN_MODE_0.9167': 'uint8',
#  'FLOORSMIN_MODE_0.9583': 'uint8',
#  'FLOORSMIN_MODE_1.0': 'uint8',
#  'FONDKAPREMONT_MODE_org spec account': 'uint8',
#  'FONDKAPREMONT_MODE_reg oper account': 'uint8',
#  'FONDKAPREMONT_MODE_reg oper spec account': 'uint8',
#  'HOUR_APPR_PROCESS_START_1': 'uint8',
#  'HOUR_APPR_PROCESS_START_10': 'uint8',
#  'HOUR_APPR_PROCESS_START_11': 'uint8',
#  'HOUR_APPR_PROCESS_START_12': 'uint8',
#  'HOUR_APPR_PROCESS_START_13': 'uint8',
#  'HOUR_APPR_PROCESS_START_14': 'uint8',
#  'HOUR_APPR_PROCESS_START_15': 'uint8',
#  'HOUR_APPR_PROCESS_START_16': 'uint8',
#  'HOUR_APPR_PROCESS_START_17': 'uint8',
#  'HOUR_APPR_PROCESS_START_18': 'uint8',
#  'HOUR_APPR_PROCESS_START_19': 'uint8',
#  'HOUR_APPR_PROCESS_START_2': 'uint8',
#  'HOUR_APPR_PROCESS_START_20': 'uint8',
#  'HOUR_APPR_PROCESS_START_21': 'uint8',
#  'HOUR_APPR_PROCESS_START_22': 'uint8',
#  'HOUR_APPR_PROCESS_START_23': 'uint8',
#  'HOUR_APPR_PROCESS_START_3': 'uint8',
#  'HOUR_APPR_PROCESS_START_4': 'uint8',
#  'HOUR_APPR_PROCESS_START_5': 'uint8',
#  'HOUR_APPR_PROCESS_START_6': 'uint8',
#  'HOUR_APPR_PROCESS_START_7': 'uint8',
#  'HOUR_APPR_PROCESS_START_8': 'uint8',
#  'HOUR_APPR_PROCESS_START_9': 'uint8',
#  'HOUSETYPE_MODE_nan': 'uint8',
#  'HOUSETYPE_MODE_specific housing': 'uint8',
#  'HOUSETYPE_MODE_terraced house': 'uint8',
#  'LIVE_CITY_NOT_WORK_CITY_1': 'uint8',
#  'LIVE_REGION_NOT_WORK_REGION_1': 'uint8',
#  'NAME_CONTRACT_TYPE_Revolving loans': 'uint8',
#  'NAME_EDUCATION_TYPE_Higher education': 'uint8',
#  'NAME_EDUCATION_TYPE_Incomplete higher': 'uint8',
#  'NAME_EDUCATION_TYPE_Lower secondary': 'uint8',
#  'NAME_EDUCATION_TYPE_Secondary / secondary special': 'uint8',
#  'NAME_FAMILY_STATUS_Married': 'uint8',
#  'NAME_FAMILY_STATUS_Separated': 'uint8',
#  'NAME_FAMILY_STATUS_Single / not married': 'uint8',
#  'NAME_FAMILY_STATUS_Unknown': 'uint8',
#  'NAME_FAMILY_STATUS_Widow': 'uint8',
#  'NAME_HOUSING_TYPE_House / apartment': 'uint8',
#  'NAME_HOUSING_TYPE_Municipal apartment': 'uint8',
#  'NAME_HOUSING_TYPE_Office apartment': 'uint8',
#  'NAME_HOUSING_TYPE_Rented apartment': 'uint8',
#  'NAME_HOUSING_TYPE_With parents': 'uint8',
#  'NAME_INCOME_TYPE_Commercial associate': 'uint8',
#  'NAME_INCOME_TYPE_Maternity leave': 'uint8',
#  'NAME_INCOME_TYPE_Pensioner': 'uint8',
#  'NAME_INCOME_TYPE_State servant': 'uint8',
#  'NAME_INCOME_TYPE_Student': 'uint8',
#  'NAME_INCOME_TYPE_Unemployed': 'uint8',
#  'NAME_INCOME_TYPE_Working': 'uint8',
#  'NAME_TYPE_SUITE_Family': 'uint8',
#  'NAME_TYPE_SUITE_Group of people': 'uint8',
#  'NAME_TYPE_SUITE_Other_A': 'uint8',
#  'NAME_TYPE_SUITE_Other_B': 'uint8',
#  'NAME_TYPE_SUITE_Spouse, partner': 'uint8',
#  'NAME_TYPE_SUITE_Unaccompanied': 'uint8',
#  'NAME_TYPE_SUITE_nan': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_1.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_10.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_11.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_12.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_13.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_14.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_15.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_16.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_17.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_18.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_19.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_2.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_20.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_21.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_22.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_23.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_24.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_25.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_26.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_27.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_28.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_29.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_3.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_30.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_348.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_352.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_353.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_354.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_4.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_47.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_5.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_6.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_7.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_8.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_9.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_1.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_10.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_11.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_12.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_13.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_14.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_15.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_16.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_17.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_18.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_19.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_2.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_20.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_21.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_22.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_23.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_24.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_25.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_26.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_27.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_28.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_29.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_3.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_30.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_344.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_349.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_351.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_4.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_47.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_5.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_6.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_7.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_8.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_9.0': 'uint8',
#  'OCCUPATION_TYPE_Cleaning staff': 'uint8',
#  'OCCUPATION_TYPE_Cooking staff': 'uint8',
#  'OCCUPATION_TYPE_Core staff': 'uint8',
#  'OCCUPATION_TYPE_Drivers': 'uint8',
#  'OCCUPATION_TYPE_HR staff': 'uint8',
#  'OCCUPATION_TYPE_High skill tech staff': 'uint8',
#  'OCCUPATION_TYPE_IT staff': 'uint8',
#  'OCCUPATION_TYPE_Laborers': 'uint8',
#  'OCCUPATION_TYPE_Low-skill Laborers': 'uint8',
#  'OCCUPATION_TYPE_Managers': 'uint8',
#  'OCCUPATION_TYPE_Medicine staff': 'uint8',
#  'OCCUPATION_TYPE_Private service staff': 'uint8',
#  'OCCUPATION_TYPE_Realty agents': 'uint8',
#  'OCCUPATION_TYPE_Sales staff': 'uint8',
#  'OCCUPATION_TYPE_Secretaries': 'uint8',
#  'OCCUPATION_TYPE_Security staff': 'uint8',
#  'OCCUPATION_TYPE_Waiters/barmen staff': 'uint8',
#  'OCCUPATION_TYPE_nan': 'uint8',
#  'ORGANIZATION_TYPE_Agriculture': 'uint8',
#  'ORGANIZATION_TYPE_Bank': 'uint8',
#  'ORGANIZATION_TYPE_Business Entity Type 1': 'uint8',
#  'ORGANIZATION_TYPE_Business Entity Type 2': 'uint8',
#  'ORGANIZATION_TYPE_Business Entity Type 3': 'uint8',
#  'ORGANIZATION_TYPE_Cleaning': 'uint8',
#  'ORGANIZATION_TYPE_Construction': 'uint8',
#  'ORGANIZATION_TYPE_Culture': 'uint8',
#  'ORGANIZATION_TYPE_Electricity': 'uint8',
#  'ORGANIZATION_TYPE_Emergency': 'uint8',
#  'ORGANIZATION_TYPE_Government': 'uint8',
#  'ORGANIZATION_TYPE_Hotel': 'uint8',
#  'ORGANIZATION_TYPE_Housing': 'uint8',
#  'ORGANIZATION_TYPE_Industry: type 1': 'uint8',
#  'ORGANIZATION_TYPE_Industry: type 10': 'uint8',
#  'ORGANIZATION_TYPE_Industry: type 11': 'uint8',
#  'ORGANIZATION_TYPE_Industry: type 12': 'uint8',
#  'ORGANIZATION_TYPE_Industry: type 13': 'uint8',
#  'ORGANIZATION_TYPE_Industry: type 2': 'uint8',
#  'ORGANIZATION_TYPE_Industry: type 3': 'uint8',
#  'ORGANIZATION_TYPE_Industry: type 4': 'uint8',
#  'ORGANIZATION_TYPE_Industry: type 5': 'uint8',
#  'ORGANIZATION_TYPE_Industry: type 6': 'uint8',
#  'ORGANIZATION_TYPE_Industry: type 7': 'uint8',
#  'ORGANIZATION_TYPE_Industry: type 8': 'uint8',
#  'ORGANIZATION_TYPE_Industry: type 9': 'uint8',
#  'ORGANIZATION_TYPE_Insurance': 'uint8',
#  'ORGANIZATION_TYPE_Kindergarten': 'uint8',
#  'ORGANIZATION_TYPE_Legal Services': 'uint8',
#  'ORGANIZATION_TYPE_Medicine': 'uint8',
#  'ORGANIZATION_TYPE_Military': 'uint8',
#  'ORGANIZATION_TYPE_Mobile': 'uint8',
#  'ORGANIZATION_TYPE_Other': 'uint8',
#  'ORGANIZATION_TYPE_Police': 'uint8',
#  'ORGANIZATION_TYPE_Postal': 'uint8',
#  'ORGANIZATION_TYPE_Realtor': 'uint8',
#  'ORGANIZATION_TYPE_Religion': 'uint8',
#  'ORGANIZATION_TYPE_Restaurant': 'uint8',
#  'ORGANIZATION_TYPE_School': 'uint8',
#  'ORGANIZATION_TYPE_Security': 'uint8',
#  'ORGANIZATION_TYPE_Security Ministries': 'uint8',
#  'ORGANIZATION_TYPE_Self-employed': 'uint8',
#  'ORGANIZATION_TYPE_Services': 'uint8',
#  'ORGANIZATION_TYPE_Telecom': 'uint8',
#  'ORGANIZATION_TYPE_Trade: type 1': 'uint8',
#  'ORGANIZATION_TYPE_Trade: type 2': 'uint8',
#  'ORGANIZATION_TYPE_Trade: type 3': 'uint8',
#  'ORGANIZATION_TYPE_Trade: type 4': 'uint8',
#  'ORGANIZATION_TYPE_Trade: type 5': 'uint8',
#  'ORGANIZATION_TYPE_Trade: type 6': 'uint8',
#  'ORGANIZATION_TYPE_Trade: type 7': 'uint8',
#  'ORGANIZATION_TYPE_Transport: type 1': 'uint8',
#  'ORGANIZATION_TYPE_Transport: type 2': 'uint8',
#  'ORGANIZATION_TYPE_Transport: type 3': 'uint8',
#  'ORGANIZATION_TYPE_Transport: type 4': 'uint8',
#  'ORGANIZATION_TYPE_University': 'uint8',
#  'ORGANIZATION_TYPE_XNA': 'uint8',
#  'OWN_CAR_AGE_1.0': 'uint8',
#  'OWN_CAR_AGE_10.0': 'uint8',
#  'OWN_CAR_AGE_11.0': 'uint8',
#  'OWN_CAR_AGE_12.0': 'uint8',
#  'OWN_CAR_AGE_13.0': 'uint8',
#  'OWN_CAR_AGE_14.0': 'uint8',
#  'OWN_CAR_AGE_15.0': 'uint8',
#  'OWN_CAR_AGE_16.0': 'uint8',
#  'OWN_CAR_AGE_17.0': 'uint8',
#  'OWN_CAR_AGE_18.0': 'uint8',
#  'OWN_CAR_AGE_19.0': 'uint8',
#  'OWN_CAR_AGE_2.0': 'uint8',
#  'OWN_CAR_AGE_20.0': 'uint8',
#  'OWN_CAR_AGE_21.0': 'uint8',
#  'OWN_CAR_AGE_22.0': 'uint8',
#  'OWN_CAR_AGE_23.0': 'uint8',
#  'OWN_CAR_AGE_24.0': 'uint8',
#  'OWN_CAR_AGE_25.0': 'uint8',
#  'OWN_CAR_AGE_26.0': 'uint8',
#  'OWN_CAR_AGE_27.0': 'uint8',
#  'OWN_CAR_AGE_28.0': 'uint8',
#  'OWN_CAR_AGE_29.0': 'uint8',
#  'OWN_CAR_AGE_3.0': 'uint8',
#  'OWN_CAR_AGE_30.0': 'uint8',
#  'OWN_CAR_AGE_31.0': 'uint8',
#  'OWN_CAR_AGE_32.0': 'uint8',
#  'OWN_CAR_AGE_33.0': 'uint8',
#  'OWN_CAR_AGE_34.0': 'uint8',
#  'OWN_CAR_AGE_35.0': 'uint8',
#  'OWN_CAR_AGE_36.0': 'uint8',
#  'OWN_CAR_AGE_37.0': 'uint8',
#  'OWN_CAR_AGE_38.0': 'uint8',
#  'OWN_CAR_AGE_39.0': 'uint8',
#  'OWN_CAR_AGE_4.0': 'uint8',
#  'OWN_CAR_AGE_40.0': 'uint8',
#  'OWN_CAR_AGE_41.0': 'uint8',
#  'OWN_CAR_AGE_42.0': 'uint8',
#  'OWN_CAR_AGE_43.0': 'uint8',
#  'OWN_CAR_AGE_44.0': 'uint8',
#  'OWN_CAR_AGE_45.0': 'uint8',
#  'OWN_CAR_AGE_46.0': 'uint8',
#  'OWN_CAR_AGE_47.0': 'uint8',
#  'OWN_CAR_AGE_48.0': 'uint8',
#  'OWN_CAR_AGE_49.0': 'uint8',
#  'OWN_CAR_AGE_5.0': 'uint8',
#  'OWN_CAR_AGE_50.0': 'uint8',
#  'OWN_CAR_AGE_51.0': 'uint8',
#  'OWN_CAR_AGE_52.0': 'uint8',
#  'OWN_CAR_AGE_54.0': 'uint8',
#  'OWN_CAR_AGE_55.0': 'uint8',
#  'OWN_CAR_AGE_56.0': 'uint8',
#  'OWN_CAR_AGE_57.0': 'uint8',
#  'OWN_CAR_AGE_6.0': 'uint8',
#  'OWN_CAR_AGE_63.0': 'uint8',
#  'OWN_CAR_AGE_64.0': 'uint8',
#  'OWN_CAR_AGE_65.0': 'uint8',
#  'OWN_CAR_AGE_69.0': 'uint8',
#  'OWN_CAR_AGE_7.0': 'uint8',
#  'OWN_CAR_AGE_74.0': 'uint8',
#  'OWN_CAR_AGE_8.0': 'uint8',
#  'OWN_CAR_AGE_9.0': 'uint8',
#  'OWN_CAR_AGE_91.0': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.00029': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.000533': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.000938': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.001276': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.001333': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.001417': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.002042': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.002134': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.002506': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.003069': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.0031219999999999998': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.003540999999999999': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.0038130000000000004': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.0038179999999999998': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.004849': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.00496': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.005002': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.005084': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.005144': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.005313': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.0060079999999999995': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.006207': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.006233': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.006296': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.006305': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.006629': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.006670999999999999': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.006852': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.00702': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.007114': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.007120000000000001': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.007273999999999998': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.007305': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.00733': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.008019': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.008068': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.00823': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.008473999999999999': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.008575': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.008625': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.008865999999999999': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.009175': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.009334': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.009549': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.00963': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.009656999999999999': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.010006000000000001': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.010032': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.010147': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.010276': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.0105': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.010556': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.010643000000000001': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.010966': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.011656999999999999': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.011703': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.014464': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.014519999999999996': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.015221': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.016612000000000002': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.018029': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.018209': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.018634': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.018801': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.01885': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.019101': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.019688999999999998': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.020246': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.020713': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.022625': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.0228': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.02461': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.025164': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.026392000000000002': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.028663': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.030755': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.031329': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.032561': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.035792000000000004': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.04622': 'uint8',
#  'REGION_POPULATION_RELATIVE_0.072508': 'uint8',
#  'REGION_RATING_CLIENT_2': 'uint8',
#  'REGION_RATING_CLIENT_3': 'uint8',
#  'REGION_RATING_CLIENT_W_CITY_1': 'uint8',
#  'REGION_RATING_CLIENT_W_CITY_2': 'uint8',
#  'REGION_RATING_CLIENT_W_CITY_3': 'uint8',
#  'REG_CITY_NOT_LIVE_CITY_1': 'uint8',
#  'REG_CITY_NOT_WORK_CITY_1': 'uint8',
#  'REG_REGION_NOT_LIVE_REGION_1': 'uint8',
#  'REG_REGION_NOT_WORK_REGION_1': 'uint8',
#  'WALLSMATERIAL_MODE_Mixed': 'uint8',
#  'WALLSMATERIAL_MODE_Monolithic': 'uint8',
#  'WALLSMATERIAL_MODE_Others': 'uint8',
#  'WALLSMATERIAL_MODE_Panel': 'uint8',
#  'WALLSMATERIAL_MODE_Stone, brick': 'uint8',
#  'WALLSMATERIAL_MODE_Wooden': 'uint8',
#  'WALLSMATERIAL_MODE_nan': 'uint8',
#  'WEEKDAY_APPR_PROCESS_START_MONDAY': 'uint8',
#  'WEEKDAY_APPR_PROCESS_START_SATURDAY': 'uint8',
#  'WEEKDAY_APPR_PROCESS_START_SUNDAY': 'uint8',
#  'WEEKDAY_APPR_PROCESS_START_THURSDAY': 'uint8',
#  'WEEKDAY_APPR_PROCESS_START_TUESDAY': 'uint8',
#  'WEEKDAY_APPR_PROCESS_START_WEDNESDAY': 'uint8',
#  'AMT_ANNUITY_FLAG_1.0': 'uint8',
#  'AMT_GOODS_PRICE_FLAG_1.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_DAY_FLAG_1.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_HOUR_FLAG_1.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_MON_FLAG_1.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_QRT_FLAG_1.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_WEEK_FLAG_1.0': 'uint8',
#  'AMT_REQ_CREDIT_BUREAU_YEAR_FLAG_1.0': 'uint8',
#  'APARTMENTS_AVG_FLAG_1.0': 'uint8',
#  'APARTMENTS_MEDI_FLAG_1.0': 'uint8',
#  'APARTMENTS_MODE_FLAG_1.0': 'uint8',
#  'BASEMENTAREA_AVG_FLAG_1.0': 'uint8',
#  'BASEMENTAREA_MEDI_FLAG_1.0': 'uint8',
#  'BASEMENTAREA_MODE_FLAG_1.0': 'uint8',
#  'COMMONAREA_AVG_FLAG_1.0': 'uint8',
#  'COMMONAREA_MEDI_FLAG_1.0': 'uint8',
#  'COMMONAREA_MODE_FLAG_1.0': 'uint8',
#  'DAYS_LAST_PHONE_CHANGE_FLAG_1.0': 'uint8',
#  'DEF_30_CNT_SOCIAL_CIRCLE_FLAG_1.0': 'uint8',
#  'DEF_60_CNT_SOCIAL_CIRCLE_FLAG_1.0': 'uint8',
#  'ELEVATORS_AVG_FLAG_1.0': 'uint8',
#  'ELEVATORS_MEDI_FLAG_1.0': 'uint8',
#  'ELEVATORS_MODE_FLAG_1.0': 'uint8',
#  'ENTRANCES_AVG_FLAG_1.0': 'uint8',
#  'ENTRANCES_MEDI_FLAG_1.0': 'uint8',
#  'ENTRANCES_MODE_FLAG_1.0': 'uint8',
#  'EXT_SOURCE_1_FLAG_1.0': 'uint8',
#  'EXT_SOURCE_2_FLAG_1.0': 'uint8',
#  'EXT_SOURCE_3_FLAG_1.0': 'uint8',
#  'FLOORSMAX_AVG_FLAG_1.0': 'uint8',
#  'FLOORSMAX_MEDI_FLAG_1.0': 'uint8',
#  'FLOORSMAX_MODE_FLAG_1.0': 'uint8',
#  'FLOORSMIN_AVG_FLAG_1.0': 'uint8',
#  'FLOORSMIN_MEDI_FLAG_1.0': 'uint8',
#  'FLOORSMIN_MODE_FLAG_1.0': 'uint8',
#  'LANDAREA_AVG_FLAG_1.0': 'uint8',
#  'LANDAREA_MEDI_FLAG_1.0': 'uint8',
#  'LANDAREA_MODE_FLAG_1.0': 'uint8',
#  'LIVINGAPARTMENTS_AVG_FLAG_1.0': 'uint8',
#  'LIVINGAPARTMENTS_MEDI_FLAG_1.0': 'uint8',
#  'LIVINGAPARTMENTS_MODE_FLAG_1.0': 'uint8',
#  'LIVINGAREA_AVG_FLAG_1.0': 'uint8',
#  'LIVINGAREA_MEDI_FLAG_1.0': 'uint8',
#  'LIVINGAREA_MODE_FLAG_1.0': 'uint8',
#  'NONLIVINGAPARTMENTS_AVG_FLAG_1.0': 'uint8',
#  'NONLIVINGAPARTMENTS_MEDI_FLAG_1.0': 'uint8',
#  'NONLIVINGAPARTMENTS_MODE_FLAG_1.0': 'uint8',
#  'NONLIVINGAREA_AVG_FLAG_1.0': 'uint8',
#  'NONLIVINGAREA_MEDI_FLAG_1.0': 'uint8',
#  'NONLIVINGAREA_MODE_FLAG_1.0': 'uint8',
#  'OBS_30_CNT_SOCIAL_CIRCLE_FLAG_1.0': 'uint8',
#  'OBS_60_CNT_SOCIAL_CIRCLE_FLAG_1.0': 'uint8',
#  'OWN_CAR_AGE_FLAG_1.0': 'uint8',
#  'TOTALAREA_MODE_FLAG_1.0': 'uint8',
#  'YEARS_BEGINEXPLUATATION_AVG_FLAG_1.0': 'uint8',
#  'YEARS_BEGINEXPLUATATION_MEDI_FLAG_1.0': 'uint8',
#  'YEARS_BEGINEXPLUATATION_MODE_FLAG_1.0': 'uint8',
#  'YEARS_BUILD_AVG_FLAG_1.0': 'uint8',
#  'YEARS_BUILD_MEDI_FLAG_1.0': 'uint8',
#  'YEARS_BUILD_MODE_FLAG_1.0': 'uint8',
#  'DAYS_EMPLOYED_FLAG_1.0': 'uint8',
#  'BU_CNT_CREDIT_PROLONG_max_1.0': 'uint8',
#  'BU_CNT_CREDIT_PROLONG_max_2.0': 'uint8',
#  'BU_CNT_CREDIT_PROLONG_max_3.0': 'uint8',
#  'BU_CNT_CREDIT_PROLONG_max_4.0': 'uint8',
#  'BU_CNT_CREDIT_PROLONG_max_5.0': 'uint8',
#  'BU_CNT_CREDIT_PROLONG_max_6.0': 'uint8',
#  'BU_CNT_CREDIT_PROLONG_max_7.0': 'uint8',
#  'BU_CNT_CREDIT_PROLONG_max_8.0': 'uint8',
#  'BU_CNT_CREDIT_PROLONG_max_9.0': 'uint8',
#  'BU_CNT_CREDIT_PROLONG_max_nan': 'uint8',
#  'BU_recent_3_status_0%_max_0.3333333333333333': 'uint8',
#  'BU_recent_3_status_0%_max_0.5': 'uint8',
#  'BU_recent_3_status_0%_max_0.6666666666666666': 'uint8',
#  'BU_recent_3_status_0%_max_1.0': 'uint8',
#  'BU_recent_3_status_0%_max_nan': 'uint8',
#  'BU_recent_3_status_1%_max_0.3333333333333333': 'uint8',
#  'BU_recent_3_status_1%_max_0.5': 'uint8',
#  'BU_recent_3_status_1%_max_0.6666666666666666': 'uint8',
#  'BU_recent_3_status_1%_max_1.0': 'uint8',
#  'BU_recent_3_status_1%_max_nan': 'uint8',
#  'BU_recent_3_status_2%_max_0.3333333333333333': 'uint8',
#  'BU_recent_3_status_2%_max_0.6666666666666666': 'uint8',
#  'BU_recent_3_status_2%_max_1.0': 'uint8',
#  'BU_recent_3_status_2%_max_nan': 'uint8',
#  'BU_recent_3_status_2%_mean_0.007407407407407406': 'uint8',
#  'BU_recent_3_status_2%_mean_0.01075268817204301': 'uint8',
#  'BU_recent_3_status_2%_mean_0.011494252873563218': 'uint8',
#  'BU_recent_3_status_2%_mean_0.011904761904761904': 'uint8',
#  'BU_recent_3_status_2%_mean_0.013333333333333329': 'uint8',
#  'BU_recent_3_status_2%_mean_0.013888888888888888': 'uint8',
#  'BU_recent_3_status_2%_mean_0.014492753623188403': 'uint8',
#  'BU_recent_3_status_2%_mean_0.01515151515151515': 'uint8',
#  'BU_recent_3_status_2%_mean_0.015873015873015872': 'uint8',
#  'BU_recent_3_status_2%_mean_0.016666666666666666': 'uint8',
#  'BU_recent_3_status_2%_mean_0.017543859649122806': 'uint8',
#  'BU_recent_3_status_2%_mean_0.018518518518518517': 'uint8',
#  'BU_recent_3_status_2%_mean_0.0196078431372549': 'uint8',
#  'BU_recent_3_status_2%_mean_0.020833333333333332': 'uint8',
#  'BU_recent_3_status_2%_mean_0.02222222222222222': 'uint8',
#  'BU_recent_3_status_2%_mean_0.023809523809523808': 'uint8',
#  'BU_recent_3_status_2%_mean_0.02564102564102564': 'uint8',
#  'BU_recent_3_status_2%_mean_0.02631578947368421': 'uint8',
#  'BU_recent_3_status_2%_mean_0.026666666666666658': 'uint8',
#  'BU_recent_3_status_2%_mean_0.027777777777777776': 'uint8',
#  'BU_recent_3_status_2%_mean_0.0303030303030303': 'uint8',
#  'BU_recent_3_status_2%_mean_0.031746031746031744': 'uint8',
#  'BU_recent_3_status_2%_mean_0.03333333333333333': 'uint8',
#  'BU_recent_3_status_2%_mean_0.037037037037037035': 'uint8',
#  'BU_recent_3_status_2%_mean_0.041666666666666664': 'uint8',
#  'BU_recent_3_status_2%_mean_0.04444444444444444': 'uint8',
#  'BU_recent_3_status_2%_mean_0.047619047619047616': 'uint8',
#  'BU_recent_3_status_2%_mean_0.05': 'uint8',
#  'BU_recent_3_status_2%_mean_0.05128205128205128': 'uint8',
#  'BU_recent_3_status_2%_mean_0.05555555555555555': 'uint8',
#  'BU_recent_3_status_2%_mean_0.0606060606060606': 'uint8',
#  'BU_recent_3_status_2%_mean_0.06666666666666668': 'uint8',
#  'BU_recent_3_status_2%_mean_0.07142857142857142': 'uint8',
#  'BU_recent_3_status_2%_mean_0.07407407407407407': 'uint8',
#  'BU_recent_3_status_2%_mean_0.07692307692307693': 'uint8',
#  'BU_recent_3_status_2%_mean_0.08': 'uint8',
#  'BU_recent_3_status_2%_mean_0.08333333333333333': 'uint8',
#  'BU_recent_3_status_2%_mean_0.09090909090909093': 'uint8',
#  'BU_recent_3_status_2%_mean_0.09523809523809523': 'uint8',
#  'BU_recent_3_status_2%_mean_0.1': 'uint8',
#  'BU_recent_3_status_2%_mean_0.1111111111111111': 'uint8',
#  'BU_recent_3_status_2%_mean_0.11904761904761905': 'uint8',
#  'BU_recent_3_status_2%_mean_0.125': 'uint8',
#  'BU_recent_3_status_2%_mean_0.13333333333333333': 'uint8',
#  'BU_recent_3_status_2%_mean_0.14285714285714285': 'uint8',
#  'BU_recent_3_status_2%_mean_0.16666666666666666': 'uint8',
#  'BU_recent_3_status_2%_mean_0.19047619047619047': 'uint8',
#  'BU_recent_3_status_2%_mean_0.2': 'uint8',
#  'BU_recent_3_status_2%_mean_0.2083333333333333': 'uint8',
#  'BU_recent_3_status_2%_mean_0.2121212121212121': 'uint8',
#  'BU_recent_3_status_2%_mean_0.2222222222222222': 'uint8',
#  'BU_recent_3_status_2%_mean_0.25': 'uint8',
#  'BU_recent_3_status_2%_mean_0.26666666666666666': 'uint8',
#  'BU_recent_3_status_2%_mean_0.3333333333333333': 'uint8',
#  'BU_recent_3_status_2%_mean_0.5555555555555555': 'uint8',
#  'BU_recent_3_status_2%_mean_0.6666666666666666': 'uint8',
#  'BU_recent_3_status_2%_mean_nan': 'uint8',
#  'BU_recent_3_status_3%_max_0.3333333333333333': 'uint8',
#  'BU_recent_3_status_3%_max_0.6666666666666666': 'uint8',
#  'BU_recent_3_status_3%_max_1.0': 'uint8',
#  'BU_recent_3_status_3%_max_nan': 'uint8',
#  'BU_recent_3_status_3%_mean_0.005747126436781609': 'uint8',
#  'BU_recent_3_status_3%_mean_0.007407407407407406': 'uint8',
#  'BU_recent_3_status_3%_mean_0.01515151515151515': 'uint8',
#  'BU_recent_3_status_3%_mean_0.015873015873015872': 'uint8',
#  'BU_recent_3_status_3%_mean_0.017543859649122806': 'uint8',
#  'BU_recent_3_status_3%_mean_0.0196078431372549': 'uint8',
#  'BU_recent_3_status_3%_mean_0.020833333333333332': 'uint8',
#  'BU_recent_3_status_3%_mean_0.02222222222222222': 'uint8',
#  'BU_recent_3_status_3%_mean_0.023809523809523808': 'uint8',
#  'BU_recent_3_status_3%_mean_0.02564102564102564': 'uint8',
#  'BU_recent_3_status_3%_mean_0.027777777777777776': 'uint8',
#  'BU_recent_3_status_3%_mean_0.0303030303030303': 'uint8',
#  'BU_recent_3_status_3%_mean_0.03333333333333333': 'uint8',
#  'BU_recent_3_status_3%_mean_0.037037037037037035': 'uint8',
#  'BU_recent_3_status_3%_mean_0.041666666666666664': 'uint8',
#  'BU_recent_3_status_3%_mean_0.047619047619047616': 'uint8',
#  'BU_recent_3_status_3%_mean_0.05128205128205128': 'uint8',
#  'BU_recent_3_status_3%_mean_0.05555555555555555': 'uint8',
#  'BU_recent_3_status_3%_mean_0.0606060606060606': 'uint8',
#  'BU_recent_3_status_3%_mean_0.06666666666666668': 'uint8',
#  'BU_recent_3_status_3%_mean_0.07407407407407407': 'uint8',
#  'BU_recent_3_status_3%_mean_0.08333333333333333': 'uint8',
#  'BU_recent_3_status_3%_mean_0.09523809523809523': 'uint8',
#  'BU_recent_3_status_3%_mean_0.1': 'uint8',
#  'BU_recent_3_status_3%_mean_0.1111111111111111': 'uint8',
#  'BU_recent_3_status_3%_mean_0.13333333333333333': 'uint8',
#  'BU_recent_3_status_3%_mean_0.16666666666666666': 'uint8',
#  'BU_recent_3_status_3%_mean_0.2222222222222222': 'uint8',
#  'BU_recent_3_status_3%_mean_0.3333333333333333': 'uint8',
#  'BU_recent_3_status_3%_mean_0.6666666666666666': 'uint8',
#  'BU_recent_3_status_3%_mean_nan': 'uint8',
#  'BU_recent_3_status_4%_max_0.3333333333333333': 'uint8',
#  'BU_recent_3_status_4%_max_0.6666666666666666': 'uint8',
#  'BU_recent_3_status_4%_max_nan': 'uint8',
#  'BU_recent_3_status_4%_mean_0.015873015873015872': 'uint8',
#  'BU_recent_3_status_4%_mean_0.017543859649122806': 'uint8',
#  'BU_recent_3_status_4%_mean_0.018518518518518517': 'uint8',
#  'BU_recent_3_status_4%_mean_0.0196078431372549': 'uint8',
#  'BU_recent_3_status_4%_mean_0.020833333333333332': 'uint8',
#  'BU_recent_3_status_4%_mean_0.02222222222222222': 'uint8',
#  ...}

# %%
# Apply the newly read csv with correct dtypes
# It seemed not necessary to transform it to dict: final_df_dtype_dict = final_df_dtype_dict.to_dict()
# final_df = final_df.astype(final_df_dtypes)
# # Or when reading the dataset csv (must transform it to dict)
# final_df = pd.read_csv('filepath', dtype = final_df_dtypes)

# %%
final_df = \
pd.read_csv('../../../BDSE12-Group3/datasets/homecdt_ss_output/ss_fteng_fromBDSE12_03G_HomeCredit_V1_20200201b.csv'\
           , dtype= final_df_dtypes)
# final_df = pd.read_csv('filepath', dtype = final_df_dtypes)

# %%
final_df.shape
# Out:
# (356255, 5782)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356255 entries, 0 to 356254
# Columns: 5782 entries, SK_ID_CURR to CC_('ccb_SK_DPD_delay_count', 'median')_median_na
# dtypes: float32(498), int64(3), uint32(1), uint8(5280)
# memory usage: 2.4 GB

# %%
# int_df.max().max(), int_df.min().min()

# %%
# float_df.max().max(), float_df.min().min()

# %%
# Do this only once for each dataset
def reduce_mem_usage3(props):
    props.info(verbose=False)
    
    int_colName = props.columns[props.dtypes == (np.int64 or np.int32)]
    float_colName = props.columns[props.dtypes == (np.float64 or np.float32)]
    int_df = props.loc[:, int_colName]
    float_df = props.loc[:, float_colName]
    print(int_df.shape)
    print(float_df.shape)
    
    assert int_df.shape[1] + float_df.shape[1] == props.shape[1]
    assert all(np.isfinite(int_df).all().value_counts())==True
    assert all(np.isfinite(float_df).all().value_counts())==True
    
    print("=============================================================")
    start_mem_usg = props.memory_usage().sum() / 1024**2 
    print("Memory usage of properties dataframe is :",start_mem_usg," MB")
    print("=============================================================")
    print("Start working on integers...")
    int_df[int_df.columns[(int_df.min()>=0) & (int_df.max()<255)]] = \
    int_df.loc[:, int_df.columns[(int_df.min()>=0) & (int_df.max()<255)]].astype(np.uint8, copy=False)
    int_df.info(verbose=False)
    print("=============================================================")

    int_df[int_df.columns[(int_df.min()>=0) &(int_df.max() >= 255) & (int_df.max()<65535)]] = \
    int_df.loc[:, int_df.columns[(int_df.min()>=0) &(int_df.max() >= 255) & (int_df.max()<65535)]] \
    .astype(np.uint16, copy=False)
    int_df.info(verbose=False)
    print("=============================================================")

    int_df[int_df.columns[(int_df.min()>=0) &(int_df.max() >= 65535) & (int_df.max()<4294967295)]] = \
    int_df.loc[:, int_df.columns[(int_df.min()>=0) &(int_df.max() >= 65535) & (int_df.max()<4294967295)]] \
    .astype(np.uint32, copy=False)
    int_df.info(verbose=False)
    print("=============================================================")
    print("Start working on floats...")
    float_df = float_df.astype(np.float32)
    float_df.info(verbose=False)

#     props[props.columns[(props.min()>=0) &(props.max() >= 4294967295)]] = \
#     props.loc[:, props.columns[(props.min()>=0) &(props.max() >= 4294967295)]] \
#     .astype(np.uint64, copy=False)
#     props.info(verbose=False)
#     print("=============================================================")
    print("Combining ints & floats...")
    props = pd.concat([int_df, float_df], axis = 'columns')
    print("Complete")
    print("___MEMORY USAGE AFTER COMPLETION:___")
    mem_usg = props.memory_usage().sum() / 1024**2 
    print("Memory usage is: ",mem_usg," MB")
    print("This is ",100*mem_usg/start_mem_usg,"% of the initial size")
    
    props.dtypes.to_csv('./final_df_dtypes.csv')
    print("./final_df_dtypes.csv was exported")
    
    return props

# %%
# # Do this only once for each dataset, then use the exported dtype series.
# final_df = reduce_mem_usage3(final_df)

# %%
# Export the dtypes Series to csv for future use
# final_df.dtypes.to_csv('../../../BDSE12-Group3/datasets/homecdt_ss_output/ss_fteng_fromBDSE12_03G_HomeCredit_V1_20200201b_dtypes_series.csv')

# %%
print(final_df['TARGET'].isna().sum(), 
      final_df['TARGET'].dtypes)
# Out:
# 48744 float32

# %% [markdown]
# # LightGBM 模型

# %%
def timer(title):
    t0 = time.time()
    yield
    print("{} - done in {:.0f}s".format(title, time.time() - t0))

def kfold_lightgbm(df, num_folds = 5, stratified = True, debug= False):
    # Divide in training/validation and test data
    train_df = df[df['TARGET'].notnull()]
    test_df = df[df['TARGET'].isnull()]
    print("Starting LightGBM goss. Train shape: {}, test shape: {}".format(train_df.shape, test_df.shape))
    del df
    gc.collect()
    # Cross validation model
    if stratified:
        folds = StratifiedKFold(n_splits= num_folds, shuffle=True, random_state=924)
    else:
        folds = KFold(n_splits= num_folds, shuffle=True, random_state=924)
    # Create arrays and dataframes to store results
    oof_preds = np.zeros(train_df.shape[0])
    sub_preds = np.zeros(test_df.shape[0])
    feature_importance_df = pd.DataFrame()
    feats = [f for f in train_df.columns if f not in ['TARGET','SK_ID_CURR','SK_ID_BUREAU','SK_ID_PREV','index']]
    
    for n_fold, (train_idx, valid_idx) in enumerate(folds.split(train_df[feats], train_df['TARGET'])):
        dtrain = lgb.Dataset(data=train_df[feats].iloc[train_idx], 
                             label=train_df['TARGET'].iloc[train_idx], 
                             free_raw_data=False, silent=True)
        dvalid = lgb.Dataset(data=train_df[feats].iloc[valid_idx], 
                             label=train_df['TARGET'].iloc[valid_idx], 
                             free_raw_data=False, silent=True)

        # LightGBM parameters found by Bayesian optimization
        params = {
            'objective': 'binary',
            'boosting_type': 'goss',
            'nthread': 4,
            'learning_rate': 0.02,  # 02,
            'num_leaves': 31, #20,33
            'tree_learner': 'voting',
            'colsample_bytree': 0.9497036,
            'subsample': 0.8715623,
            'subsample_freq': 0,
            'max_depth': 7, #8,7
            'reg_alpha': 0.041545473,
            'reg_lambda': 0.0735294,
            'min_split_gain': 0.0222415,
            'min_data_in_leaf': 49, # ss add
#             'min_child_weight': 1, # 60,39
            'seed': 924,
            'verbose': 2000,
            'metric': 'auc',
            'max_bin': 127,
#             'histogram_pool_size': 20480
#             'device' : 'gpu',
#             'gpu_platform_id': 0,
#             'gpu_device_id':0
        }
        
        clf = lgb.train(
            params=params,
            train_set=dtrain,
            num_boost_round=20000,
            valid_sets=[dtrain, dvalid],
            early_stopping_rounds=200,
            verbose_eval=2000
        )

        oof_preds[valid_idx] = clf.predict(dvalid.data)
        sub_preds += clf.predict(test_df[feats]) / folds.n_splits

        fold_importance_df = pd.DataFrame()
        fold_importance_df["feature"] = feats
        fold_importance_df["importance"] = clf.feature_importance(importance_type='gain')
        fold_importance_df["fold"] = n_fold + 1
        feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
        print('Fold %2d AUC : %.6f' % (n_fold + 1, roc_auc_score(dvalid.label, oof_preds[valid_idx])))
        del clf, dtrain, dvalid
        gc.collect()

    print('Full AUC score %.6f' % roc_auc_score(train_df['TARGET'], oof_preds))
    # Write submission file and plot feature importance
    if not debug:
        sub_df = test_df[['SK_ID_CURR']].copy()
        sub_df['TARGET'] = sub_preds
        sub_df[['SK_ID_CURR', 'TARGET']].to_csv('../../../BDSE12-Group3/datasets/homecdt_ss_output/homecdt_submission_LGBM.csv', index= False)
    display_importances(feature_importance_df)
    return feature_importance_df

# Display/plot feature importance
def display_importances(feature_importance_df_):
    cols = feature_importance_df_[["feature", "importance"]].groupby("feature").mean().sort_values(by="importance", ascending=False)[:40].index
    best_features = feature_importance_df_.loc[feature_importance_df_.feature.isin(cols)]
    plt.figure(figsize=(8, 10))
    sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False))
    plt.title('LightGBM Features (avg over folds)')
    plt.tight_layout
    plt.savefig('../../../BDSE12-Group3/datasets/homecdt_ss_output/lgbm_importances01.png')

# %% [markdown]
# ## boosting_type：goss

# %%
init_time = time.time()
kfold_lightgbm(final_df,10)
print("Elapsed time={:5.2f} sec.".format(time.time() - init_time))
# Out:
# Starting LightGBM goss. Train shape: (307511, 5782), test shape: (48744, 5782)

# %% [markdown]
# ## boosting_type：gbdt

# %%
init_time = time.time()
kfold_lightgbm(final_df, 10)
print("Elapsed time={:5.2f} sec.".format(time.time() - init_time))

# %% [markdown]
# ## boosting_type：dart

# %%
init_time = time.time()
kfold_lightgbm(final_df,10)
print("Elapsed time={:5.2f} sec.".format(time.time() - init_time))

# %% [markdown]
# ## boosting_type：rf

# %%
init_time = time.time()
kfold_lightgbm(final_df,10)
print("Elapsed time={:5.2f} sec.".format(time.time() - init_time))

# %% [markdown]
# # XGBoost 模型

# %%
from numba import cuda
cuda.select_device(0)
cuda.close()

# %%
import numpy as np
import pandas as pd
import gc
import time
from contextlib import contextmanager
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import KFold, StratifiedKFold
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import pickle

# %%
def kfold_xgb(df, num_folds, stratified = True, debug= False):
    # Divide in training/validation and test data
    train_df = df[df['TARGET'].notnull()]
    test_df = df[df['TARGET'].isnull()]
    print("Starting XGBoost. Train shape: {}, test shape: {}".format(train_df.shape, test_df.shape))
    del df
    gc.collect()
    # Cross validation model
    if stratified:
        folds = StratifiedKFold(n_splits= num_folds, shuffle=True, random_state=1054)
    else:
        folds = KFold(n_splits= num_folds, shuffle=True, random_state=1054)
    # Create arrays and dataframes to store results
    oof_preds = np.zeros(train_df.shape[0])
    sub_preds = np.zeros(test_df.shape[0])
    feature_importance_df = pd.DataFrame()
    feats = [f for f in train_df.columns if f not in ['TARGET','SK_ID_CURR','SK_ID_BUREAU','SK_ID_PREV','index']]
    
    for n_fold, (train_idx, valid_idx) in enumerate(folds.split(train_df[feats], train_df['TARGET'])):
        #if n_fold == 0: # REmove for full K-fold run
        cuda.select_device(0)
        cuda.close()
        train_x, train_y = train_df[feats].iloc[train_idx], train_df['TARGET'].iloc[train_idx]
        valid_x, valid_y = train_df[feats].iloc[valid_idx], train_df['TARGET'].iloc[valid_idx]

        clf = XGBClassifier(learning_rate =0.01, 
                            n_estimators=5000, 
                            max_depth=4, 
                            min_child_weight=5,
#                             tree_method='gpu_hist',
                            subsample=0.8, 
                            colsample_bytree=0.8, 
                            objective= 'binary:logistic',
                            nthread=4,
                            scale_pos_weight=2.5,
                            seed=28,
                            reg_lambda = 1.2)
        
#         clf = pickle.load(open('test.pickle','rb'))
        
        cuda.select_device(0)
        cuda.close()
        
        clf.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], 
            eval_metric= 'auc', verbose= 1000, early_stopping_rounds= 200)
        
        cuda.select_device(0)
        cuda.close()
        
        oof_preds[valid_idx] = clf.predict_proba(valid_x)[:, 1]
        sub_preds += clf.predict_proba(test_df[feats])[:, 1] # / folds.n_splits # - Uncomment for K-fold 

        fold_importance_df = pd.DataFrame()
        fold_importance_df["feature"] = feats
        fold_importance_df["importance"] = clf.feature_importances_
        fold_importance_df["fold"] = n_fold + 1
        feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
        print('Fold %2d AUC : %.6f' % (n_fold + 1, roc_auc_score(valid_y, oof_preds[valid_idx])))
        del clf, train_x, train_y, valid_x, valid_y
        gc.collect()

        np.save("xgb_oof_preds_1", oof_preds)
        np.save("xgb_sub_preds_1", sub_preds)
        
        cuda.select_device(0)
        cuda.close()
        
    
    clf = pickle.load(open('test.pickle','rb'))
    # print('Full AUC score %.6f' % roc_auc_score(train_df['TARGET'], oof_preds))
    # Write submission file and plot feature importance
    if not debug:
        test_df['TARGET'] = sub_preds
        test_df[['SK_ID_CURR', 'TARGET']].to_csv('submission_XGBoost_GPU.csv', index= False)
    #display_importances(feature_importance_df)
    #return feature_importance_df

# Display/plot feature importance
def display_importances(feature_importance_df_):
    cols = feature_importance_df_[["feature", "importance"]].groupby("feature").mean().sort_values(by="importance", ascending=False)[:40].index
    best_features = feature_importance_df_.loc[feature_importance_df_.feature.isin(cols)]
    plt.figure(figsize=(8, 10))
    sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False))
    plt.title('XGBoost Features (avg over folds)')
    plt.tight_layout()
    plt.savefig('xgb_importances02.png')

# %%
init_time = time.time()
kfold_xgb(final_df, 5)
print("Elapsed time={:5.2f} sec.".format(time.time() - init_time))
