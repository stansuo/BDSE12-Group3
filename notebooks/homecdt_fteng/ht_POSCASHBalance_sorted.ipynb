# %% [markdown]
# #### 可增加欄位
# - CNT_INSTALMENT_FUTURE 會減少，那是否會增加？
# - 實際還款期數除以CNT_INSTALMENT
# - CNT_INSTALMENT是否有減少過或增加過，各是多少？
# - 每筆SK_ID_PREV的CNT_INSTALMENT的最大、最小、中位數
# - 每筆SK_ID_PREV的最大、平均SK_DPD
# - 每筆SK_ID_PREV的最大MONTHS_BALANCE
# - 每筆SK_ID_PREV的最小MONTHS_BALANCE
# - 幾期之後completed(比起CNT_INSTALMENT)
# - SK_DPD出現次數(比起CNT_INSTALMENT)
# - SK_DPD最大值

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
pos = pd.read_csv('../../datasets/homecdt_eda/POS_CASH_balance.csv')
pos.head(20)
# Out:
#     SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  CNT_INSTALMENT  \
# 0      1803195      182943             -31            48.0
# 1      1715348      367990             -33            36.0
# 2      1784872      397406             -32            12.0
# 3      1903291      269225             -35            48.0
# 4      2341044      334279             -35            36.0
# 5      2207092      342166             -32            12.0
# 6      1110516      204376             -38            48.0
# 7      1387235      153211             -35            36.0
# 8      1220500      112740             -31            12.0
# 9      2371489      274851             -32            24.0
# 10     2328294      287361             -32            12.0
# 11     2023570      237959             -39            12.0
# 12     1258390      278261             -32            36.0
# 13     1627166      146161             -33            24.0
# 14     1711625      131467             -34            12.0
# ...

# %%
pos.sort_values(by=['SK_ID_CURR','SK_ID_PREV','MONTHS_BALANCE'],inplace=True)
pd.set_option('display.max_rows',None)
pos.head(200)
# Out:
#          SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  CNT_INSTALMENT  \
# 7167007     1369693      100001             -57             4.0
# 8789081     1369693      100001             -56             4.0
# 7823681     1369693      100001             -55             4.0
# 4704415     1369693      100001             -54             4.0
# 2197888     1369693      100001             -53             4.0
# 1261679     1851984      100001             -96             4.0
# 1891462     1851984      100001             -95             4.0
# 8531326     1851984      100001             -94             4.0
# 4928574     1851984      100001             -93             4.0
# 8473918     1038818      100002             -19            24.0
# 2012884     1038818      100002             -18            24.0
# 5258607     1038818      100002             -17            24.0
# 1216849     1038818      100002             -16            24.0
# 9849444     1038818      100002             -15            24.0
# ...

# %%
pos.head(2000)
# Out:
#          SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  CNT_INSTALMENT  \
# 7167007     1369693      100001             -57             4.0
# 8789081     1369693      100001             -56             4.0
# 7823681     1369693      100001             -55             4.0
# 4704415     1369693      100001             -54             4.0
# 2197888     1369693      100001             -53             4.0
# 1261679     1851984      100001             -96             4.0
# 1891462     1851984      100001             -95             4.0
# 8531326     1851984      100001             -94             4.0
# 4928574     1851984      100001             -93             4.0
# 8473918     1038818      100002             -19            24.0
# 2012884     1038818      100002             -18            24.0
# 5258607     1038818      100002             -17            24.0
# 1216849     1038818      100002             -16            24.0
# 9849444     1038818      100002             -15            24.0
# ...
