# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
bureau = pd.read_csv("C:/final/home-credit-default-risk/bureau.csv")

# %%
bureau.head(30)
# Out:
#     SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 0       215354       5714462        Closed      currency 1         -497
# 1       215354       5714463        Active      currency 1         -208
# 2       215354       5714464        Active      currency 1         -203
# 3       215354       5714465        Active      currency 1         -203
# 4       215354       5714466        Active      currency 1         -629
# 5       215354       5714467        Active      currency 1         -273
# 6       215354       5714468        Active      currency 1          -43
# 7       162297       5714469        Closed      currency 1        -1896
# 8       162297       5714470        Closed      currency 1        -1146
# 9       162297       5714471        Active      currency 1        -1146
# 10      162297       5714472        Active      currency 1        -1146
# 11      162297       5714473        Closed      currency 1        -2456
# 12      162297       5714474        Active      currency 1         -277
# 13      402440       5714475        Active      currency 1          -96
# 14      238881       5714482        Closed      currency 1         -318
# 15      238881       5714484        Closed      currency 1        -2911
# 16      238881       5714485        Closed      currency 1        -2148
# 17      238881       5714486        Active      currency 1         -381
# 18      238881       5714487        Active      currency 1          -95
# 19      238881       5714488        Closed      currency 1         -444
# 20      238881       5714489        Active      currency 1         -392
# 21      222183       5714491        Active      currency 1         -784
# 22      222183       5714492        Active      currency 1         -774
# 23      222183       5714493        Active      currency 1         -395
# 24      222183       5714495        Closed      currency 1        -2744
# 25      222183       5714496        Closed      currency 1        -1103
# 26      222183       5714497        Active      currency 1         -315
# 27      426155       5714498        Closed      currency 1        -1331
# 28      426155       5714499        Closed      currency 1        -2534
# 29      426155       5714500        Closed      currency 1         -845
#
#     CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 0                    0               -153.0             -153.0
# 1                    0               1075.0                NaN
# 2                    0                528.0                NaN
# 3                    0                  NaN                NaN
# 4                    0               1197.0                NaN
# 5                    0              27460.0                NaN
# 6                    0                 79.0                NaN
# 7                    0              -1684.0            -1710.0
# 8                    0               -811.0             -840.0
# 9                    0               -484.0                NaN
# 10                   0               -180.0                NaN
# 11                   0               -629.0             -825.0
# 12                   0               5261.0                NaN
# 13                   0                269.0                NaN
# 14                   0               -187.0             -187.0
# 15                   0              -2607.0            -2604.0
# 16                   0              -1595.0             -987.0
# 17                   0                  NaN                NaN
# 18                   0               1720.0                NaN
# 19                   0                -77.0              -77.0
# 20                   0                  NaN                NaN
# 21                   0               1008.0                NaN
# 22                   0                625.0                NaN
# 23                   0               1431.0                NaN
# 24                   0              -2561.0            -2559.0
# 25                   0                 -7.0             -343.0
# 26                   0               1512.0                NaN
# 27                   0               -994.0            -1023.0
# 28                   0              -2352.0            -2347.0
# 29                   0               -480.0             -480.0
#
#     AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# 0                      NaN                   0        91323.00
# 1                      NaN                   0       225000.00
# 2                      NaN                   0       464323.50
# 3                      NaN                   0        90000.00
# 4                 77674.50                   0      2700000.00
# 5                     0.00                   0       180000.00
# 6                     0.00                   0        42103.80
# 7                 14985.00                   0        76878.45
# 8                     0.00                   0       103007.70
# 9                     0.00                   0         4500.00
# 10                    0.00                   0       337500.00
# 11                     NaN                   0       675000.00
# 12                    0.00                   0      7033500.00
# 13                    0.00                   0        89910.00
# 14                     NaN                   0            0.00
# 15                     NaN                   0        48555.00
# 16                     NaN                   0       135000.00
# 17                     NaN                   0       450000.00
# 18                     NaN                   0        67500.00
# 19                    0.00                   0       107184.06
# 20                    0.00                   0       252000.00
# 21                    0.00                   0            0.00
# 22                     NaN                   0       127840.50
# 23                     NaN                   0      1350000.00
# 24                  310.50                   0        18157.50
# 25                20493.27                   0       675000.00
# 26                88821.00                   0      3709552.50
# 27                 1350.00                   0        39433.50
# 28                     NaN                   0        38830.50
# 29                    0.00                   0        67500.00
#
#     AMT_CREDIT_SUM_DEBT  AMT_CREDIT_SUM_LIMIT  AMT_CREDIT_SUM_OVERDUE  \
# 0                 0.000                   NaN                     0.0
# 1            171342.000                   NaN                     0.0
# 2                   NaN                   NaN                     0.0
# 3                   NaN                   NaN                     0.0
# 4                   NaN                   NaN                     0.0
# 5             71017.380            108982.620                     0.0
# 6             42103.800                 0.000                     0.0
# 7                 0.000                 0.000                     0.0
# 8                 0.000                 0.000                     0.0
# 9                 0.000                 0.000                     0.0
# 10                0.000                 0.000                     0.0
# 11                0.000                 0.000                     0.0
# 12                  NaN                   NaN                     0.0
# 13            76905.000                 0.000                     0.0
# 14                0.000                 0.000                     0.0
# 15                  NaN                   NaN                     0.0
# 16                  NaN                   NaN                     0.0
# 17           520920.000                   NaN                     0.0
# 18             8131.500                   NaN                     0.0
# 19                0.000                 0.000                     0.0
# 20            23679.000            228320.100                     0.0
# 21             -411.615               411.615                     0.0
# 22                0.000                 0.000                     0.0
# 23          1185493.500                 0.000                     0.0
# 24                  NaN                   NaN                     0.0
# 25                0.000                 0.000                     0.0
# 26                  NaN                   NaN                     0.0
# 27                0.000                 0.000                     0.0
# 28                0.000                 0.000                     0.0
# 29                0.000                 0.000                     0.0
#
#         CREDIT_TYPE  DAYS_CREDIT_UPDATE  AMT_ANNUITY
# 0   Consumer credit                -131          NaN
# 1       Credit card                 -20          NaN
# 2   Consumer credit                 -16          NaN
# 3       Credit card                 -16          NaN
# 4   Consumer credit                 -21          NaN
# 5       Credit card                 -31          NaN
# 6   Consumer credit                 -22          NaN
# 7   Consumer credit               -1710          NaN
# 8   Consumer credit                -840          NaN
# 9       Credit card                -690          NaN
# 10      Credit card                -690          NaN
# 11  Consumer credit                -706          NaN
# 12         Mortgage                 -31          NaN
# 13  Consumer credit                 -22          NaN
# 14      Credit card                -185          NaN
# 15  Consumer credit               -2601          NaN
# 16  Consumer credit                -984          NaN
# 17  Consumer credit                  -4          NaN
# 18      Credit card                  -7          NaN
# 19  Consumer credit                 -71          NaN
# 20      Credit card                 -22          NaN
# 21      Credit card                -694          NaN
# 22      Credit card                -210          NaN
# 23  Consumer credit                 -24          NaN
# 24  Consumer credit               -2559          NaN
# 25  Consumer credit                -343          NaN
# 26         Car loan                 -32          NaN
# 27  Consumer credit               -1023          NaN
# 28  Consumer credit               -2345          NaN
# 29  Consumer credit                -480          NaN

# %%
bureau.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1716428 entries, 0 to 1716427
# Data columns (total 17 columns):
# SK_ID_CURR                int64
# SK_ID_BUREAU              int64
# CREDIT_ACTIVE             object
# CREDIT_CURRENCY           object
# DAYS_CREDIT               int64
# CREDIT_DAY_OVERDUE        int64
# DAYS_CREDIT_ENDDATE       float64
# DAYS_ENDDATE_FACT         float64
# AMT_CREDIT_MAX_OVERDUE    float64
# CNT_CREDIT_PROLONG        int64
# AMT_CREDIT_SUM            float64
# AMT_CREDIT_SUM_DEBT       float64
# AMT_CREDIT_SUM_LIMIT      float64
# AMT_CREDIT_SUM_OVERDUE    float64
# CREDIT_TYPE               object
# DAYS_CREDIT_UPDATE        int64
# AMT_ANNUITY               float64
# dtypes: float64(8), int64(6), object(3)
# memory usage: 222.6+ MB

# %%
bureau.isna().sum()
# Out:
# SK_ID_CURR                      0
# SK_ID_BUREAU                    0
# CREDIT_ACTIVE                   0
# CREDIT_CURRENCY                 0
# DAYS_CREDIT                     0
# CREDIT_DAY_OVERDUE              0
# DAYS_CREDIT_ENDDATE        105553
# DAYS_ENDDATE_FACT          633653
# AMT_CREDIT_MAX_OVERDUE    1124488
# CNT_CREDIT_PROLONG              0
# AMT_CREDIT_SUM                 13
# AMT_CREDIT_SUM_DEBT        257669
# AMT_CREDIT_SUM_LIMIT       591780
# AMT_CREDIT_SUM_OVERDUE          0
# CREDIT_TYPE                     0
# DAYS_CREDIT_UPDATE              0
# AMT_ANNUITY               1226791
# dtype: int64

# %%
bureau.isna().sum()/bureau.shape[0] # 約定每年還款金額&最大欠款額NA比例很高
# Out:
# SK_ID_CURR                0.000000
# SK_ID_BUREAU              0.000000
# CREDIT_ACTIVE             0.000000
# CREDIT_CURRENCY           0.000000
# DAYS_CREDIT               0.000000
# CREDIT_DAY_OVERDUE        0.000000
# DAYS_CREDIT_ENDDATE       0.061496
# DAYS_ENDDATE_FACT         0.369170
# AMT_CREDIT_MAX_OVERDUE    0.655133
# CNT_CREDIT_PROLONG        0.000000
# AMT_CREDIT_SUM            0.000008
# AMT_CREDIT_SUM_DEBT       0.150119
# AMT_CREDIT_SUM_LIMIT      0.344774
# AMT_CREDIT_SUM_OVERDUE    0.000000
# CREDIT_TYPE               0.000000
# DAYS_CREDIT_UPDATE        0.000000
# AMT_ANNUITY               0.714735
# dtype: float64

# %%
bureau.groupby('CREDIT_ACTIVE')['CREDIT_DAY_OVERDUE'].describe().sort_index(by='count',ascending=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: by argument to sort_index is deprecated, please use .sort_values(by=...)
#   """Entry point for launching an IPython kernel.
#                    count        mean         std  min  25%  50%    75%     max
# CREDIT_ACTIVE
# Closed         1079273.0    0.104681   12.932319  0.0  0.0  0.0    0.0  2347.0
# Active          630607.0    1.810288   53.478929  0.0  0.0  0.0    0.0  2770.0
# Sold              6527.0   21.936418  213.269464  0.0  0.0  0.0    0.0  2792.0
# Bad debt            21.0  313.619048  513.969209  0.0  0.0  0.0  366.0  1761.0

# %%
bureau.loc[bureau['CREDIT_DAY_OVERDUE']!=0] # 逾期天數不等於0的有4217筆
# Out:
#          SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 365          282297       5714943        Active      currency 1        -2712
# 785          408647       5715468        Active      currency 1         -313
# 936          380677       5715645        Active      currency 1        -2659
# 1575         218135       5716400        Active      currency 1        -2543
# 1791         229323       5716671        Active      currency 1         -757
# ...             ...           ...           ...             ...          ...
# 1707319      226956       5027625        Active      currency 1          -52
# 1707833      108883       5028638        Active      currency 1         -907
# 1709570      141935       5582069        Active      currency 1          -80
# 1709789      385777       5582323        Active      currency 1         -126
# 1713547      177331       5085700        Active      currency 1        -2576
#
#          CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 365                    2603              -2498.0                NaN
# 785                       6                233.0                NaN
# 936                      30              -2353.0                NaN
# 1575                   2156              -2172.0                NaN
# 1791                    496                  NaN                NaN
# ...                     ...                  ...                ...
# 1707319                  19                224.0                NaN
# 1707833                  20                553.0                NaN
# 1709570                  20               1016.0                NaN
# 1709789                  24                606.0                NaN
# 1713547                  60              -2392.0                NaN
#
#          AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# 365                      4590.0                   0       24696.000
# 785                         NaN                   0      417208.500
# 936                         NaN                   0       57024.000
# 1575                        NaN                   0       45000.000
# 1791                        NaN                   0      225000.000
# ...                         ...                 ...             ...
# 1707319                  2151.0                   0       23701.500
# 1707833                     NaN                   0      135000.000
# 1709570                    22.5                   0      166137.255
# 1709789                     NaN                   0      405000.000
# 1713547                     NaN                   0       19512.000
#
#          AMT_CREDIT_SUM_DEBT  AMT_CREDIT_SUM_LIMIT  AMT_CREDIT_SUM_OVERDUE  \
# 365                  231.525                   0.0                 231.525
# 785               214947.000                   0.0                 288.000
# 936                    0.000                   NaN                  58.500
# 1575                     NaN                   NaN                 504.000
# 1791                     NaN                   NaN              169582.500
# ...                      ...                   ...                     ...
# 1707319            18819.000                   0.0                  22.500
# 1707833           137119.500                   NaN                 193.500
# 1709570           160812.000                   0.0                  22.500
# 1709789           362002.500                   0.0                  22.500
# 1713547                0.000                   NaN                 171.000
#
#              CREDIT_TYPE  DAYS_CREDIT_UPDATE  AMT_ANNUITY
# 365      Consumer credit               -1077          NaN
# 785      Consumer credit                  -5          NaN
# 936      Consumer credit                -493          NaN
# 1575     Consumer credit               -2156          NaN
# 1791     Consumer credit                  -4          NaN
# ...                  ...                 ...          ...
# 1707319  Consumer credit                 -18          NaN
# 1707833      Credit card                 -13          0.0
# 1709570  Consumer credit                 -11          NaN
# 1709789  Consumer credit                  -9          NaN
# 1713547  Consumer credit                -516          NaN
#
# [4217 rows x 17 columns]

# %%
bureau.loc[(bureau['CREDIT_DAY_OVERDUE']!=0) & (bureau['CREDIT_ACTIVE']=='Closed')] # 已經Closed的還有逾期天數？
# Out:
#          SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 9446         350002       5725982        Closed      currency 1        -2276
# 17100        323596       5190659        Closed      currency 1        -2261
# 43881        392205       5214368        Closed      currency 1        -2591
# 46064        247863       5217154        Closed      currency 1        -2355
# 50560        233380       5222730        Closed      currency 1        -2349
# ...             ...           ...           ...             ...          ...
# 1600459      454392       5335298        Closed      currency 1        -2103
# 1628047      381777       5567059        Closed      currency 1        -2669
# 1641060      329467       5550615        Closed      currency 1        -1561
# 1659270      433302       6644337        Closed      currency 1        -1397
# 1679083      163338       6654943        Closed      currency 1        -2282
#
#          CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 9446                   1715              -1972.0            -1724.0
# 17100                  1572              -1957.0            -1575.0
# 43881                  1694              -2103.0            -1699.0
# 46064                  1651              -2051.0            -1656.0
# 50560                   745              -1254.0             -887.0
# ...                     ...                  ...                ...
# 1600459                1918              -1921.0            -1251.0
# 1628047                2347              -2487.0            -2109.0
# 1641060                1278              -1255.0            -1261.0
# 1659270                1272              -1275.0            -1262.0
# 1679083                2220              -2124.0            -1358.0
#
#          AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# 9446                        NaN                   0         16186.5
# 17100                       NaN                   0        113094.0
# 43881                       NaN                   0         26995.5
# 46064                       NaN                   0         16929.0
# 50560                       NaN                   0        249300.0
# ...                         ...                 ...             ...
# 1600459                     NaN                   0         27783.0
# 1628047                     NaN                   0         38898.0
# 1641060                     NaN                   0         36031.5
# 1659270                     NaN                   0         78300.0
# 1679083                     NaN                   0         16128.0
#
#          AMT_CREDIT_SUM_DEBT  AMT_CREDIT_SUM_LIMIT  AMT_CREDIT_SUM_OVERDUE  \
# 9446                     0.0                   0.0                   585.0
# 17100                    0.0                   0.0                   220.5
# 43881                    0.0                   0.0                     9.0
# 46064                    0.0                   0.0                    54.0
# 50560                    0.0                   0.0                     9.0
# ...                      ...                   ...                     ...
# 1600459                  0.0                   0.0                    58.5
# 1628047                  0.0                   0.0                    36.0
# 1641060                  0.0                   0.0                     0.0
# 1659270                  0.0                   0.0                     0.0
# 1679083                  0.0                   0.0                 63949.5
#
#              CREDIT_TYPE  DAYS_CREDIT_UPDATE  AMT_ANNUITY
# 9446     Consumer credit               -1714          NaN
# 17100    Consumer credit               -1571          NaN
# 43881    Consumer credit               -1693          NaN
# 46064    Consumer credit               -1650          NaN
# 50560    Consumer credit                -744          NaN
# ...                  ...                 ...          ...
# 1600459  Consumer credit               -1248          NaN
# 1628047  Consumer credit                -428          0.0
# 1641060  Consumer credit               -1254          NaN
# 1659270  Consumer credit               -1256          NaN
# 1679083  Consumer credit               -1338          NaN
#
# [83 rows x 17 columns]

# %%
bureau.loc[bureau['SK_ID_CURR']==282297] # 試著解釋一個人的狀況
# Out:
#          SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 365          282297       5714943        Active      currency 1        -2712
# 366          282297       5714944        Closed      currency 1         -789
# 367          282297       5714945        Closed      currency 1         -907
# 368          282297       5714947        Active      currency 1         -419
# 369          282297       5714948        Active      currency 1         -158
# 370          282297       5714952        Active      currency 1        -2614
# 371          282297       5714953        Active      currency 1        -1797
# 372          282297       5714954        Closed      currency 1          -49
# 1672029      282297       5714946        Closed      currency 1        -1524
# 1672030      282297       5714950        Closed      currency 1        -1298
# 1672031      282297       5714951        Closed      currency 1        -1298
#
#          CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 365                    2603              -2498.0                NaN
# 366                       0               -424.0             -516.0
# 367                       0               -542.0             -532.0
# 368                       0                886.0                NaN
# 369                       0                573.0                NaN
# 370                       0              -1899.0                NaN
# 371                       0              -1053.0                NaN
# 372                       0                316.0              -39.0
# 1672029                   0               -793.0             -791.0
# 1672030                   0               -934.0             -875.0
# 1672031                   0               -934.0             -875.0
#
#          AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# 365                      4590.0                   0         24696.0
# 366                         NaN                   0        139860.0
# 367                         NaN                   0        450000.0
# 368                         NaN                   0        112500.0
# 369                         NaN                   0        466200.0
# 370                         0.0                   0        225000.0
# 371                         0.0                   0        225000.0
# 372                         0.0                   0        650335.5
# 1672029                     NaN                   0        935640.0
# 1672030                     NaN                   0        232258.5
# 1672031                     NaN                   0        232258.5
#
#          AMT_CREDIT_SUM_DEBT  AMT_CREDIT_SUM_LIMIT  AMT_CREDIT_SUM_OVERDUE  \
# 365                  231.525                 0.000                 231.525
# 366                    0.000                 0.000                   0.000
# 367                    0.000                 0.000                   0.000
# 368                78016.500                 0.000                   0.000
# 369               435573.000                 0.000                   0.000
# 370                    0.000             59083.785                   0.000
# 371               115592.400                 0.000                   0.000
# 372                      NaN                   NaN                   0.000
# 1672029                0.000                 0.000                   0.000
# 1672030                  NaN                   NaN                   0.000
# 1672031                  NaN                   NaN                   0.000
#
#              CREDIT_TYPE  DAYS_CREDIT_UPDATE  AMT_ANNUITY
# 365      Consumer credit               -1077          NaN
# 366      Consumer credit                -513          NaN
# 367      Consumer credit                -513          NaN
# 368          Credit card                 -67          NaN
# 369      Consumer credit                 -67          NaN
# 370          Credit card               -2187          NaN
# 371          Credit card               -1424          NaN
# 372             Car loan                 -39          NaN
# 1672029  Consumer credit                -706          NaN
# 1672030  Consumer credit                -872          NaN
# 1672031  Consumer credit                -872          NaN

# %%
(bureau['DAYS_CREDIT']-bureau['CREDIT_DAY_OVERDUE']).dropna()
# Out:
# 0          -497
# 1          -208
# 2          -203
# 3          -203
# 4          -629
#            ...
# 1716423     -44
# 1716424   -2648
# 1716425   -1809
# 1716426   -1878
# 1716427    -463
# Length: 1716428, dtype: int64

# %%
((bureau['DAYS_CREDIT']-bureau['CREDIT_DAY_OVERDUE']).dropna()<=0).sum()/1716428 # 檢查是否逾期天數皆小於DAYS_CREDIT
# Out:
# 1.0

# %%
bureau.loc[(bureau['CREDIT_ACTIVE']=='Active') & (bureau['DAYS_CREDIT_ENDDATE']<0)] # EndDate意義不明，跟CREDIT_ACTIVE似乎沒有關係
# 從DAYS_CREDIT_ENDDATE看已經結束的貸款，狀態還是Active？
# Out:
#          SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 9            162297       5714471        Active      currency 1        -1146
# 10           162297       5714472        Active      currency 1        -1146
# 34           400486       5714506        Active      currency 1         -941
# 50           452585       5714525        Active      currency 1        -2538
# 51           452585       5714527        Active      currency 1          -42
# ...             ...           ...           ...             ...          ...
# 1716240      233665       5051918        Active      currency 1         -646
# 1716268      391091       5053479        Active      currency 1        -2361
# 1716284      435426       5053674        Active      currency 1        -1228
# 1716326      229234       5055272        Active      currency 1         -696
# 1716423      259355       5057750        Active      currency 1          -44
#
#          CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 9                         0               -484.0                NaN
# 10                        0               -180.0                NaN
# 34                        0                -17.0                NaN
# 50                        0              -1427.0                NaN
# 51                        0                -26.0                NaN
# ...                     ...                  ...                ...
# 1716240                   0               -281.0                NaN
# 1716268                   0              -1247.0                NaN
# 1716284                   0               -121.0                NaN
# 1716326                   0               -331.0                NaN
# 1716423                   0                -30.0                NaN
#
#          AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# 9                           0.0                   0          4500.0
# 10                          0.0                   0        337500.0
# 34                          NaN                   0         40500.0
# 50                          0.0                   0         45000.0
# 51                          NaN                   0         45000.0
# ...                         ...                 ...             ...
# 1716240                     NaN                   0         67500.0
# 1716268                     NaN                   0             0.0
# 1716284                     NaN                   0        270000.0
# 1716326                     NaN                   0        675000.0
# 1716423                     0.0                   0         11250.0
#
#          AMT_CREDIT_SUM_DEBT  AMT_CREDIT_SUM_LIMIT  AMT_CREDIT_SUM_OVERDUE  \
# 9                        0.0                   0.0                     0.0
# 10                       0.0                   0.0                     0.0
# 34                       0.0                   0.0                     0.0
# 50                       0.0                   0.0                     0.0
# 51                   54000.0                   0.0                     0.0
# ...                      ...                   ...                     ...
# 1716240               6205.5                   0.0                     0.0
# 1716268                171.0                   0.0                     0.0
# 1716284             264087.0                   0.0                     0.0
# 1716326             292725.0                   0.0                     0.0
# 1716423              11250.0                   0.0                     0.0
#
#              CREDIT_TYPE  DAYS_CREDIT_UPDATE  AMT_ANNUITY
# 9            Credit card                -690          NaN
# 10           Credit card                -690          NaN
# 34           Credit card                 -15          NaN
# 50           Credit card                -682          NaN
# 51       Consumer credit                 -31          NaN
# ...                  ...                 ...          ...
# 1716240  Consumer credit                -277          NaN
# 1716268      Credit card               -1025          NaN
# 1716284      Credit card                 -82          NaN
# 1716326  Consumer credit                -431          NaN
# 1716423        Microloan                 -19          NaN
#
# [76359 rows x 17 columns]

# %%
bureau.groupby('CREDIT_ACTIVE')['DAYS_ENDDATE_FACT'].describe() 
# Active的count跟上表不一樣？
## 依說明文件，'DAYS_ENDDATE_FACT'(貸款已結束幾天)應只有在Closed的狀況下有值，建議將Active狀態下的此欄都改為na(數目不多)
# Out:
#                    count         mean         std      min     25%     50%  \
# CREDIT_ACTIVE
# Active            1969.0 -1344.955815  990.683275  -2922.0 -2395.0 -1306.0
# Bad debt            10.0 -1211.900000  471.153301  -1781.0 -1538.0 -1458.5
# Closed         1079148.0 -1017.406828  713.229580 -42023.0 -1488.0  -897.0
# Sold              1648.0  -644.797937  641.664422  -2682.0 -1077.0  -327.0
#
#                   75%    max
# CREDIT_ACTIVE
# Active         -80.00   -3.0
# Bad debt      -781.75 -499.0
# Closed        -426.00    0.0
# Sold          -124.75   -5.0

# %%
bureau['CREDIT_ACTIVE'].value_counts()
# Out:
# Closed      1079273
# Active       630607
# Sold           6527
# Bad debt         21
# Name: CREDIT_ACTIVE, dtype: int64

# %%
(bureau['DAYS_CREDIT']-bureau['DAYS_CREDIT_ENDDATE']).dropna()
# Out:
# 0           -344.0
# 1          -1283.0
# 2           -731.0
# 4          -1826.0
# 5         -27733.0
#             ...
# 1716422   -33777.0
# 1716423      -14.0
# 1716424     -215.0
# 1716425     -181.0
# 1716426     -365.0
# Length: 1610875, dtype: float64

# %%
((bureau['DAYS_CREDIT']-bureau['DAYS_CREDIT_ENDDATE']).dropna()<=0).sum()/1610875
 # 檢查貸款結束天數與DAYS_CREDIT的關係。DAYS_CREDIT為CB貸款的開始日，應該都要比DAYS_CREDIT_ENDDATE(CB貸款結束日來得小)
# Out:
# 0.9998981919764104

# %%
bureau.loc[(bureau['DAYS_CREDIT'])>(bureau['DAYS_CREDIT_ENDDATE'])] # 檢查貸款結束天數與DAYS_CREDIT的關係，異常狀況，大小的關係很怪；如要使用DAYS_CREDIT_ENDDATE，建議將這幾筆刪除
# Out:
#          SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 55561        324038       5233073        Active      currency 1         -841
# 63031        273313       5001845        Active      currency 1            0
# 67507        147912       5007091        Active      currency 1         -388
# 98826        200629       6540711        Closed      currency 1        -2317
# 106353       120334       6585564        Closed      currency 1        -2579
# ...             ...           ...           ...             ...          ...
# 1595661      437755       5596368        Active      currency 1        -2697
# 1663955      141706       6649929        Closed      currency 1        -2783
# 1667368      122988       5599599        Active      currency 1         -835
# 1684396      293428       5571289        Closed      currency 1        -2252
# 1686632      120709       5574125        Closed      currency 1        -2852
#
#          CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 55561                     0             -16322.0                NaN
# 63031                     0               -222.0                NaN
# 67507                     0             -41847.0                NaN
# 98826                     0             -41824.0             -428.0
# 106353                    0             -41836.0             -687.0
# ...                     ...                  ...                ...
# 1595661                   0             -16295.0                NaN
# 1663955                   0             -41823.0             -674.0
# 1667368                   0             -16300.0                NaN
# 1684396                   0             -41846.0             -457.0
# 1686632                   0             -41841.0             -445.0
#
#          AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# 55561                      0.00                   0             0.0
# 63031                       NaN                   0       5760553.5
# 67507                      0.00                   0        225000.0
# 98826                   8271.99                   0             0.0
# 106353                     0.00                   0             0.0
# ...                         ...                 ...             ...
# 1595661                    0.00                   0             0.0
# 1663955                    0.00                   0             0.0
# 1667368                    0.00                   0             0.0
# 1684396                10323.36                   0             0.0
# 1686632                    0.00                   0             0.0
#
#          AMT_CREDIT_SUM_DEBT  AMT_CREDIT_SUM_LIMIT  AMT_CREDIT_SUM_OVERDUE  \
# 55561             264909.240                   0.0                     0.0
# 63031                  0.000                   NaN                     0.0
# 67507                  0.000              225000.0                     0.0
# 98826                  0.000                   0.0                     0.0
# 106353                 0.000                   0.0                     0.0
# ...                      ...                   ...                     ...
# 1595661           171183.600                   0.0                     0.0
# 1663955                0.000                   0.0                     0.0
# 1667368           189031.725                   0.0                     0.0
# 1684396                0.000                   0.0                     0.0
# 1686632                0.000                   0.0                     0.0
#
#                   CREDIT_TYPE  DAYS_CREDIT_UPDATE  AMT_ANNUITY
# 55561             Credit card                 -39          NaN
# 63031    Another type of loan                 -86          NaN
# 67507             Credit card                -241          NaN
# 98826             Credit card                -428          NaN
# 106353            Credit card                -687          NaN
# ...                       ...                 ...          ...
# 1595661           Credit card                 -12          NaN
# 1663955           Credit card                -674          NaN
# 1667368           Credit card                 -17          NaN
# 1684396           Credit card                -457          NaN
# 1686632           Credit card                -445          NaN
#
# [164 rows x 17 columns]

# %%
bureau.loc[(bureau['AMT_CREDIT_SUM_DEBT']==0) & (bureau['CREDIT_ACTIVE']=='Active')]
# 負債欄位意義不明，無負債應該貸款就會Close
# Out:
#          SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 9            162297       5714471        Active      currency 1        -1146
# 10           162297       5714472        Active      currency 1        -1146
# 22           222183       5714492        Active      currency 1         -774
# 31           136226       5714502        Active      currency 1         -521
# 34           400486       5714506        Active      currency 1         -941
# ...             ...           ...           ...             ...          ...
# 1716367      174236       5057234        Active      currency 1         -559
# 1716373      207024       5057311        Active      currency 1         -497
# 1716383      195589       5057399        Active      currency 1         -679
# 1716395      181001       5057523        Active      currency 1         -112
# 1716410      280228       5057642        Active      currency 1         -575
#
#          CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 9                         0               -484.0                NaN
# 10                        0               -180.0                NaN
# 22                        0                625.0                NaN
# 31                        0                551.0                NaN
# 34                        0                -17.0                NaN
# ...                     ...                  ...                ...
# 1716367                   0               1269.0                NaN
# 1716373                   0               1330.0                NaN
# 1716383                   0                416.0                NaN
# 1716395                   0               1056.0                NaN
# 1716410                   0                813.0                NaN
#
#          AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# 9                           0.0                   0          4500.0
# 10                          0.0                   0        337500.0
# 22                          NaN                   0        127840.5
# 31                          NaN                   0        112500.0
# 34                          NaN                   0         40500.0
# ...                         ...                 ...             ...
# 1716367                     0.0                   0        225000.0
# 1716373                     0.0                   0        135000.0
# 1716383                     0.0                   0        337500.0
# 1716395                     NaN                   0        418500.0
# 1716410                     NaN                   0         67500.0
#
#          AMT_CREDIT_SUM_DEBT  AMT_CREDIT_SUM_LIMIT  AMT_CREDIT_SUM_OVERDUE  \
# 9                        0.0                   0.0                     0.0
# 10                       0.0                   0.0                     0.0
# 22                       0.0                   0.0                     0.0
# 31                       0.0                   0.0                     0.0
# 34                       0.0                   0.0                     0.0
# ...                      ...                   ...                     ...
# 1716367                  0.0                   0.0                     0.0
# 1716373                  0.0                   0.0                     0.0
# 1716383                  0.0              337500.0                     0.0
# 1716395                  0.0                   0.0                     0.0
# 1716410                  0.0                   0.0                     0.0
#
#          CREDIT_TYPE  DAYS_CREDIT_UPDATE  AMT_ANNUITY
# 9        Credit card                -690          NaN
# 10       Credit card                -690          NaN
# 22       Credit card                -210          NaN
# 31       Credit card                 -30          NaN
# 34       Credit card                 -15          NaN
# ...              ...                 ...          ...
# 1716367  Credit card                -559          NaN
# 1716373  Credit card                -497          NaN
# 1716383  Credit card                -218          NaN
# 1716395  Credit card                 -39          NaN
# 1716410  Credit card                 -46          NaN
#
# [123842 rows x 17 columns]

# %%
bureau.loc[(bureau['AMT_CREDIT_SUM_DEBT']>0)]['SK_ID_CURR'].unique().shape # 多數人都有負債
# Out:
# (215542,)

# %%
bureau.loc[(bureau['AMT_CREDIT_SUM_OVERDUE']!=0) & (bureau['CREDIT_ACTIVE']=='Closed'),
           ('CREDIT_ACTIVE','CREDIT_DAY_OVERDUE','DAYS_CREDIT_ENDDATE','AMT_CREDIT_MAX_OVERDUE','AMT_CREDIT_SUM_OVERDUE')] # 有錢還沒還，但已經Closed是怎麼回事
# Out:
#         CREDIT_ACTIVE  CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  \
# 9446           Closed                1715              -1972.0
# 17100          Closed                1572              -1957.0
# 33723          Closed                   0                -87.0
# 43881          Closed                1694              -2103.0
# 46064          Closed                1651              -2051.0
# ...               ...                 ...                  ...
# 1628047        Closed                2347              -2487.0
# 1655616        Closed                   0              -1961.0
# 1679083        Closed                2220              -2124.0
# 1696803        Closed                   0               -444.0
# 1710139        Closed                   0              -2060.0
#
#          AMT_CREDIT_MAX_OVERDUE  AMT_CREDIT_SUM_OVERDUE
# 9446                        NaN                   585.0
# 17100                       NaN                   220.5
# 33723                       NaN                     9.0
# 43881                       NaN                     9.0
# 46064                       NaN                    54.0
# ...                         ...                     ...
# 1628047                     NaN                    36.0
# 1655616                     NaN                     4.5
# 1679083                     NaN                 63949.5
# 1696803                     NaN                    76.5
# 1710139                     NaN                   234.0
#
# [157 rows x 5 columns]

# %%
bureau['AMT_CREDIT_SUM_LIMIT'].describe()  # 34%的信用卡額度為na，同一人可以有值的信用卡額度平均作為代表
# Out:
# count    1.124648e+06
# mean     6.229515e+03
# std      4.503203e+04
# min     -5.864061e+05
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      4.705600e+06
# Name: AMT_CREDIT_SUM_LIMIT, dtype: float64

# %%
bureau.loc[(bureau['AMT_CREDIT_SUM_LIMIT']>0) & (bureau['CREDIT_TYPE']!='Credit card')].shape[0] # 有信用卡額度數字的紀錄中，36筆的貸款非信用卡
# Out:
# 36

# %%
bureau.loc[(bureau['AMT_CREDIT_SUM_LIMIT']>0) & (bureau['CREDIT_TYPE']=='Credit card')].shape[0] # 有信用卡額度數字的紀錄中，大部分的貸款為信用卡
# Out:
# 74119

# %%
bureau.loc[(bureau['CREDIT_TYPE']=='Credit card')].shape[0] # 信用卡貸款共402195筆
# Out:
# 402195

# %%
bureau[0:1] # 看有什麼欄位
# Out:
#    SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 0      215354       5714462        Closed      currency 1         -497
#
#    CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 0                   0               -153.0             -153.0
#
#    AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# 0                     NaN                   0         91323.0
#
#    AMT_CREDIT_SUM_DEBT  AMT_CREDIT_SUM_LIMIT  AMT_CREDIT_SUM_OVERDUE  \
# 0                  0.0                   NaN                     0.0
#
#        CREDIT_TYPE  DAYS_CREDIT_UPDATE  AMT_ANNUITY
# 0  Consumer credit                -131          NaN

# %%
bureau['CREDIT_ACTIVE'].unique()
# Out:
# array(['Closed', 'Active', 'Sold', 'Bad debt'], dtype=object)

# %%
bureau['CREDIT_ACTIVE'].unique().shape
# Out:
# (4,)

# %%
for name in bureau.columns:
    print('\n')
    print(f'{name}欄')
    if np.dtype(bureau[name])=='O' :
        print(bureau[name].unique())
    print(bureau[name].unique().shape)
# Out:
# SK_ID_CURR欄
# (305811,)
#
#
# SK_ID_BUREAU欄
# (1716428,)
#
#
# CREDIT_ACTIVE欄
# ['Closed' 'Active' 'Sold' 'Bad debt']
# (4,)
#
#
# CREDIT_CURRENCY欄
# ['currency 1' 'currency 2' 'currency 4' 'currency 3']
# (4,)
#
#
# DAYS_CREDIT欄
# (2923,)
#
#
# CREDIT_DAY_OVERDUE欄
# (942,)
#
#
# DAYS_CREDIT_ENDDATE欄
# (14097,)
#
#
# DAYS_ENDDATE_FACT欄
# (2918,)
#
#
# AMT_CREDIT_MAX_OVERDUE欄
# (68252,)
#
#
# CNT_CREDIT_PROLONG欄
# (10,)
#
#
# AMT_CREDIT_SUM欄
# (236709,)
#
#
# AMT_CREDIT_SUM_DEBT欄
# (226538,)
#
#
# AMT_CREDIT_SUM_LIMIT欄
# (51727,)
#
#
# AMT_CREDIT_SUM_OVERDUE欄
# (1616,)
#
#
# CREDIT_TYPE欄
# ['Consumer credit' 'Credit card' 'Mortgage' 'Car loan' 'Microloan'
#  'Loan for working capital replenishment' 'Loan for business development'
#  'Real estate loan' 'Unknown type of loan' 'Another type of loan'
#  'Cash loan (non-earmarked)' 'Loan for the purchase of equipment'
#  'Mobile operator loan' 'Interbank credit'
#  'Loan for purchase of shares (margin lending)']
# (15,)
#
#
# DAYS_CREDIT_UPDATE欄
# (2982,)
#
#
# AMT_ANNUITY欄
# (40322,)

# %%
bureau['CNT_CREDIT_PROLONG'].unique()
# Out:
# array([0, 2, 1, 4, 3, 5, 9, 8, 6, 7], dtype=int64)

# %%
assert bureau.apply(lambda x: x.unique().shape[0])['SK_ID_BUREAU'] == bureau.shape[0] # 確認是否每列SK_ID_BUREAU都不同

# %%
(bureau.apply(lambda x: x.unique().shape[0])/bureau.shape[0]).plot(kind='bar',rot=80)

# %%
plt.hist(bureau['CREDIT_CURRENCY'], alpha=0.5,
        histtype='stepfilled', color='steelblue',
        edgecolor='none',log=True,);

# %%
plt.hist(bureau['DAYS_CREDIT'], bins=30, alpha=0.5,
        histtype='stepfilled', color='steelblue',
        edgecolor='none');

# %%
plt.hist(bureau['CREDIT_DAY_OVERDUE'], bins=30, alpha=0.5,
        histtype='stepfilled', color='steelblue',
        edgecolor='none',log=True);

# %%
plt.hist(bureau['DAYS_CREDIT_ENDDATE'], bins=100, alpha=0.5,
        histtype='stepfilled', color='steelblue',
        edgecolor='none',log=True);

# %%
plt.hist(bureau['DAYS_ENDDATE_FACT'], bins=100, alpha=0.5,
        histtype='stepfilled', color='steelblue',
        edgecolor='none',log=True);

# %%
plt.hist(bureau['AMT_CREDIT_MAX_OVERDUE'], bins=100, alpha=0.5,
        histtype='stepfilled', color='steelblue',
        edgecolor='none',log=True);

# %%
plt.hist(bureau['CNT_CREDIT_PROLONG'], alpha=0.5,
        histtype='stepfilled', color='steelblue',
        edgecolor='none',log=True);

# %%
plt.hist(bureau['AMT_CREDIT_SUM'], bins=500, alpha=0.5,
        histtype='stepfilled', color='steelblue',
        edgecolor='none',range=(1,1000000)); # 似乎有異常值

# %%
plt.hist(bureau['AMT_CREDIT_SUM_DEBT'], alpha=0.5,
        histtype='stepfilled', color='steelblue',
        edgecolor='none',log=True);

# %%
plt.hist(bureau['AMT_CREDIT_SUM_LIMIT'], alpha=0.5,
        histtype='stepfilled', color='steelblue',
        edgecolor='none',log=True);

# %%
plt.hist(bureau['AMT_CREDIT_SUM_OVERDUE'], alpha=0.5,
        histtype='stepfilled', color='steelblue',
        edgecolor='none',log=True);

# %%
plt.hist(bureau['CREDIT_TYPE'], normed=True, alpha=0.5,
        histtype='stepfilled', color='steelblue',
        edgecolor='none',log=True,);
# Out:
# C:\Users\YEN32\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
bureau.groupby('CREDIT_TYPE')['CREDIT_TYPE'].describe().sort_index(by='count',ascending=False)
# Out:
# C:\Users\YEN32\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: by argument to sort_index is deprecated, please use .sort_values(by=...)
#   """Entry point for launching an IPython kernel.
#                                                 count unique  \
# CREDIT_TYPE
# Consumer credit                               1251615      1
# Credit card                                    402195      1
# Car loan                                        27690      1
# Mortgage                                        18391      1
# Microloan                                       12413      1
# Loan for business development                    1975      1
# Another type of loan                             1017      1
# Unknown type of loan                              555      1
# Loan for working capital replenishment            469      1
# Cash loan (non-earmarked)                          56      1
# Real estate loan                                   27      1
# Loan for the purchase of equipment                 19      1
# Loan for purchase of shares (margin lending)        4      1
# Interbank credit                                    1      1
# Mobile operator loan                                1      1
#
#                                                                                        top  \
# CREDIT_TYPE
# Consumer credit                                                            Consumer credit
# Credit card                                                                    Credit card
# Car loan                                                                          Car loan
# Mortgage                                                                          Mortgage
# Microloan                                                                        Microloan
# Loan for business development                                Loan for business development
# Another type of loan                                                  Another type of loan
# Unknown type of loan                                                  Unknown type of loan
# Loan for working capital replenishment              Loan for working capital replenishment
# Cash loan (non-earmarked)                                        Cash loan (non-earmarked)
# Real estate loan                                                          Real estate loan
# Loan for the purchase of equipment                      Loan for the purchase of equipment
# Loan for purchase of shares (margin lending)  Loan for purchase of shares (margin lending)
# Interbank credit                                                          Interbank credit
# Mobile operator loan                                                  Mobile operator loan
#
#                                                  freq
# CREDIT_TYPE
# Consumer credit                               1251615
# Credit card                                    402195
# Car loan                                        27690
# Mortgage                                        18391
# Microloan                                       12413
# Loan for business development                    1975
# Another type of loan                             1017
# Unknown type of loan                              555
# Loan for working capital replenishment            469
# Cash loan (non-earmarked)                          56
# Real estate loan                                   27
# Loan for the purchase of equipment                 19
# Loan for purchase of shares (margin lending)        4
# Interbank credit                                    1
# Mobile operator loan                                1

# %%
plt.hist(bureau['DAYS_CREDIT_UPDATE'], bins=100,  alpha=0.5,
        histtype='stepfilled', color='steelblue',
        edgecolor='none',log=True,);

# %%
plt.hist(bureau['AMT_ANNUITY'], bins=100, alpha=0.5,
        histtype='stepfilled', color='steelblue',
        edgecolor='none',log=True,);

# %% [markdown]
# 建議主表新增欄位
# 1. Active貸款金額
# 2. Active貸款金額的逾期金額比重
# 3. 平均信貸延長幾次
# 4. 信貸金額除以信用卡額度的平均
# 5. Active貸款金額與現在貸款金額的比例
# 6. 平均逾期天數
# 7. 最大逾期天數
# 8. 最近申請其他貸款的時間
# 9. 申請貸款時間的第一四分位數
